# %%
# !pip install spotipy
# Out:
# Collecting spotipy
#   Downloading spotipy-2.19.0-py3-none-any.whl (27 kB)
# Collecting requests>=2.25.0
#   Downloading requests-2.26.0-py2.py3-none-any.whl (62 kB)
# Collecting urllib3>=1.26.0
#   Downloading urllib3-1.26.7-py2.py3-none-any.whl (138 kB)
# Requirement already satisfied: six>=1.15.0 in c:\users\karo\anaconda3\lib\site-packages (from spotipy) (1.15.0)
# Collecting charset-normalizer~=2.0.0; python_version >= "3"
#   Downloading charset_normalizer-2.0.7-py3-none-any.whl (38 kB)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\karo\anaconda3\lib\site-packages (from requests>=2.25.0->spotipy) (2020.6.20)
# Requirement already satisfied: idna<4,>=2.5; python_version >= "3" in c:\users\karo\anaconda3\lib\site-packages (from requests>=2.25.0->spotipy) (2.10)
# Installing collected packages: charset-normalizer, urllib3, requests, spotipy
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.25.11
#     Uninstalling urllib3-1.25.11:
#       Successfully uninstalled urllib3-1.25.11
#   Attempting uninstall: requests
#     Found existing installation: requests 2.24.0
#     Uninstalling requests-2.24.0:
#       Successfully uninstalled requests-2.24.0
# Successfully installed charset-normalizer-2.0.7 requests-2.26.0 spotipy-2.19.0 urllib3-1.26.7

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

#Initialize SpotiPy with user credentias
sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id="xx",
                                                           client_secret="xx"))

# %%
37i9dQZF1DX4jP4eebSWR9

# %%
results = sp.user_playlist_tracks("spotify", "4SAp2pqkCTYnu3midNetQ7")
tracks = results['items']

for oset in range(100,results['total'],100):
    results = sp.user_playlist_tracks("spotify", "4SAp2pqkCTYnu3midNetQ7", offset=oset)
    tracks += results['items']
len(tracks)
# Out:
# 141

# %%
def get_playlist_tracks(username, playlist_id):
    
    results = sp.user_playlist_tracks(username, playlist_id)
    tracks = results['items']
    
    while results['next']:
        results = sp.next(results)
        tracks.extend(results['items'])
    
    return tracks

tracks = get_playlist_tracks("spotify", "4SAp2pqkCTYnu3midNetQ7")

# %%
tracks
# Out:
# [{'added_at': '2021-10-08T06:48:47Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/hbhz741mqsyfv0zafwby1nbq0'},
#    'href': 'https://api.spotify.com/v1/users/hbhz741mqsyfv0zafwby1nbq0',
#    'id': 'hbhz741mqsyfv0zafwby1nbq0',
#    'type': 'user',
#    'uri': 'spotify:user:hbhz741mqsyfv0zafwby1nbq0'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7f5Zgnp2spUuuzKplmRkt7'},
#       'href': 'https://api.spotify.com/v1/artists/7f5Zgnp2spUuuzKplmRkt7',
#       'id': '7f5Zgnp2spUuuzKplmRkt7',
#       'name': 'Lost Frequencies',
#       'type': 'artist',
#       'uri': 'spotify:artist:7f5Zgnp2spUuuzKplmRkt7'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/6ydoSd3N2mwgwBHtF6K7eX'},
#       'href': 'https://api.spotify.com/v1/artists/6ydoSd3N2mwgwBHtF6K7eX',
#       'id': '6ydoSd3N2mwgwBHtF6K7eX',
#       'name': 'Calum Scott',
#       'type': 'artist',
#       'uri': 'spotify:artist:6ydoSd3N2mwgwBHtF6K7eX'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/5YrOK7zze6egKg9a8WRcnD'},
#     'href': 'https://api.spotify.com/v1/albums/5YrOK7zze6egKg9a8WRcnD',
#     'id': '5YrOK7zze6egKg9a8WRcnD',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2738d7a7f1855b04104ba59c18b',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e028d7a7f1855b04104ba59c18b',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048518d7a7f1855b04104ba59c18b',
#       'width': 64}],
#     'name': 'Where Are You Now',
#     'release_date': '2021-07-30',
#     'release_date_precision': 'day',
#     'total_tracks': 1,
#     'type': 'album',
#     'uri': 'spotify:album:5YrOK7zze6egKg9a8WRcnD'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7f5Zgnp2spUuuzKplmRkt7'},
#      'href': 'https://api.spotify.com/v1/artists/7f5Zgnp2spUuuzKplmRkt7',
#      'id': '7f5Zgnp2spUuuzKplmRkt7',
#      'name': 'Lost Frequencies',
#      'type': 'artist',
#      'uri': 'spotify:artist:7f5Zgnp2spUuuzKplmRkt7'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/6ydoSd3N2mwgwBHtF6K7eX'},
#      'href': 'https://api.spotify.com/v1/artists/6ydoSd3N2mwgwBHtF6K7eX',
#      'id': '6ydoSd3N2mwgwBHtF6K7eX',
#      'name': 'Calum Scott',
#      'type': 'artist',
#      'uri': 'spotify:artist:6ydoSd3N2mwgwBHtF6K7eX'}],
#    'available_markets': ['AD',
#     'AE',
#     'AG',
#     'AL',
#     'AM',
#     'AO',
#     'AR',
#     'AT',
#     'AU',
#     'AZ',
#     'BA',
#     'BB',
#     'BD',
#     'BE',
#     'BF',
#     'BG',
#     'BH',
#     'BI',
#     'BJ',
#     'BN',
#     'BO',
#     'BR',
#     'BS',
#     'BT',
#     'BW',
#     'BY',
#     'BZ',
#     'CA',
#     'CH',
#     'CI',
#     'CL',
#     'CM',
#     'CO',
#     'CR',
#     'CV',
#     'CW',
#     'CY',
#     'CZ',
#     'DE',
#     'DJ',
#     'DK',
#     'DM',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FJ',
#     'FM',
#     'FR',
#     'GA',
#     'GB',
#     'GD',
#     'GE',
#     'GH',
#     'GM',
#     'GN',
#     'GQ',
#     'GR',
#     'GT',
#     'GW',
#     'GY',
#     'HK',
#     'HN',
#     'HR',
#     'HT',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JM',
#     'JO',
#     'JP',
#     'KE',
#     'KG',
#     'KH',
#     'KI',
#     'KM',
#     'KN',
#     'KR',
#     'KW',
#     'KZ',
#     'LA',
#     'LB',
#     'LC',
#     'LI',
#     'LK',
#     'LR',
#     'LS',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MG',
#     'MH',
#     'MK',
#     'ML',
#     'MN',
#     'MO',
#     'MR',
#     'MT',
#     'MU',
#     'MV',
#     'MW',
#     'MX',
#     'MY',
#     'MZ',
#     'NA',
#     'NE',
#     'NG',
#     'NI',
#     'NL',
#     'NO',
#     'NP',
#     'NR',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PG',
#     'PH',
#     'PK',
#     'PL',
#     'PS',
#     'PT',
#     'PW',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RU',
#     'RW',
#     'SA',
#     'SB',
#     'SC',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SL',
#     'SM',
#     'SN',
#     'SR',
#     'ST',
#     'SV',
#     'SZ',
#     'TD',
#     'TG',
#     'TH',
#     'TL',
#     'TN',
#     'TO',
#     'TR',
#     'TT',
#     'TV',
#     'TW',
#     'TZ',
#     'UA',
#     'UG',
#     'US',
#     'UY',
#     'UZ',
#     'VC',
#     'VN',
#     'VU',
#     'WS',
#     'XK',
#     'ZA',
#     'ZM',
#     'ZW'],
#    'disc_number': 1,
#    'duration_ms': 148197,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'BEHP42100067'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/3uUuGVFu1V7jTQL60S1r8z'},
#    'href': 'https://api.spotify.com/v1/tracks/3uUuGVFu1V7jTQL60S1r8z',
#    'id': '3uUuGVFu1V7jTQL60S1r8z',
#    'is_local': False,
#    'name': 'Where Are You Now',
#    'popularity': 89,
#    'preview_url': 'https://p.scdn.co/mp3-preview/0825558fecb2dd0c63a761fa24e9d25a6192b855?cid=5a11aee182e7428bad8cfc351a5298ec',
#    'track': True,
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:3uUuGVFu1V7jTQL60S1r8z'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2021-10-08T06:48:47Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/hbhz741mqsyfv0zafwby1nbq0'},
#    'href': 'https://api.spotify.com/v1/users/hbhz741mqsyfv0zafwby1nbq0',
#    'id': 'hbhz741mqsyfv0zafwby1nbq0',
#    'type': 'user',
#    'uri': 'spotify:user:hbhz741mqsyfv0zafwby1nbq0'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5SZUMeZ1O9tcgkSkkx1dFy'},
#       'href': 'https://api.spotify.com/v1/artists/5SZUMeZ1O9tcgkSkkx1dFy',
#       'id': '5SZUMeZ1O9tcgkSkkx1dFy',
#       'name': 'Viva La Panda',
#       'type': 'artist',
#       'uri': 'spotify:artist:5SZUMeZ1O9tcgkSkkx1dFy'}],
#     'available_markets': ['DK', 'FI', 'IS', 'NO', 'SE'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/5zrYmxJ3E9ZFqdDjRb9MKG'},
#     'href': 'https://api.spotify.com/v1/albums/5zrYmxJ3E9ZFqdDjRb9MKG',
#     'id': '5zrYmxJ3E9ZFqdDjRb9MKG',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273c090f44a485264a59a1f3bf5',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02c090f44a485264a59a1f3bf5',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851c090f44a485264a59a1f3bf5',
#       'width': 64}],
#     'name': 'Rescue You',
#     'release_date': '2021-09-10',
#     'release_date_precision': 'day',
#     'total_tracks': 1,
#     'type': 'album',
#     'uri': 'spotify:album:5zrYmxJ3E9ZFqdDjRb9MKG'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5SZUMeZ1O9tcgkSkkx1dFy'},
#      'href': 'https://api.spotify.com/v1/artists/5SZUMeZ1O9tcgkSkkx1dFy',
#      'id': '5SZUMeZ1O9tcgkSkkx1dFy',
#      'name': 'Viva La Panda',
#      'type': 'artist',
#      'uri': 'spotify:artist:5SZUMeZ1O9tcgkSkkx1dFy'}],
#    'available_markets': ['DK', 'FI', 'IS', 'NO', 'SE'],
#    'disc_number': 1,
#    'duration_ms': 164765,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'DK4YA2153101'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/6NUR2VEmFDjdW6CtN53wN3'},
#    'href': 'https://api.spotify.com/v1/tracks/6NUR2VEmFDjdW6CtN53wN3',
#    'id': '6NUR2VEmFDjdW6CtN53wN3',
#    'is_local': False,
#    'name': 'Rescue You',
#    'popularity': 34,
#    'preview_url': 'https://p.scdn.co/mp3-preview/e32a2dd4dd154c45f7defc612a968a6bbed48ace?cid=5a11aee182e7428bad8cfc351a5298ec',
#    'track': True,
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:6NUR2VEmFDjdW6CtN53wN3'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2021-10-08T06:48:47Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/hbhz741mqsyfv0zafwby1nbq0'},
#    'href': 'https://api.spotify.com/v1/users/hbhz741mqsyfv0zafwby1nbq0',
#    'id': 'hbhz741mqsyfv0zafwby1nbq0',
#    'type': 'user',
#    'uri': 'spotify:user:hbhz741mqsyfv0zafwby1nbq0'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6VlE82AXyZhHEo87D6C1RH'},
#       'href': 'https://api.spotify.com/v1/artists/6VlE82AXyZhHEo87D6C1RH',
#       'id': '6VlE82AXyZhHEo87D6C1RH',
#       'name': 'Kid On The Block',
#       'type': 'artist',
#       'uri': 'spotify:artist:6VlE82AXyZhHEo87D6C1RH'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/6wx2DYiNYOG3HGQYQSBb9j'},
#       'href': 'https://api.spotify.com/v1/artists/6wx2DYiNYOG3HGQYQSBb9j',
#       'id': '6wx2DYiNYOG3HGQYQSBb9j',
#       'name': 'Idle Days',
#       'type': 'artist',
#       'uri': 'spotify:artist:6wx2DYiNYOG3HGQYQSBb9j'}],
#     'available_markets': ['DK', 'FI', 'IS', 'NO', 'SE'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/6qaTRibLdFJXSDJPUrX0vR'},
#     'href': 'https://api.spotify.com/v1/albums/6qaTRibLdFJXSDJPUrX0vR',
#     'id': '6qaTRibLdFJXSDJPUrX0vR',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273c2838bf58e85268e596334e1',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02c2838bf58e85268e596334e1',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851c2838bf58e85268e596334e1',
#       'width': 64}],
#     'name': 'Lovely',
#     'release_date': '2021-10-08',
#     'release_date_precision': 'day',
#     'total_tracks': 1,
#     'type': 'album',
#     'uri': 'spotify:album:6qaTRibLdFJXSDJPUrX0vR'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6VlE82AXyZhHEo87D6C1RH'},
#      'href': 'https://api.spotify.com/v1/artists/6VlE82AXyZhHEo87D6C1RH',
#      'id': '6VlE82AXyZhHEo87D6C1RH',
#      'name': 'Kid On The Block',
#      'type': 'artist',
#      'uri': 'spotify:artist:6VlE82AXyZhHEo87D6C1RH'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/6wx2DYiNYOG3HGQYQSBb9j'},
#      'href': 'https://api.spotify.com/v1/artists/6wx2DYiNYOG3HGQYQSBb9j',
#      'id': '6wx2DYiNYOG3HGQYQSBb9j',
#      'name': 'Idle Days',
#      'type': 'artist',
#      'uri': 'spotify:artist:6wx2DYiNYOG3HGQYQSBb9j'}],
#    'available_markets': ['DK', 'FI', 'IS', 'NO', 'SE'],
#    'disc_number': 1,
#    'duration_ms': 169067,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'DK4YA2161401'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/7vWcdMR6ezvlXkNIzNZTIs'},
#    'href': 'https://api.spotify.com/v1/tracks/7vWcdMR6ezvlXkNIzNZTIs',
#    'id': '7vWcdMR6ezvlXkNIzNZTIs',
#    'is_local': False,
#    'name': 'Lovely',
#    'popularity': 16,
#    'preview_url': 'https://p.scdn.co/mp3-preview/c1c96cff11419efe8f5331440d5b39b6d9174c27?cid=5a11aee182e7428bad8cfc351a5298ec',
#    'track': True,
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:7vWcdMR6ezvlXkNIzNZTIs'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2021-10-08T06:48:47Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/hbhz741mqsyfv0zafwby1nbq0'},
#    'href': 'https://api.spotify.com/v1/users/hbhz741mqsyfv0zafwby1nbq0',
#    'id': 'hbhz741mqsyfv0zafwby1nbq0',
#    'type': 'user',
#    'uri': 'spotify:user:hbhz741mqsyfv0zafwby1nbq0'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0ZdCJB39o81l85QK7PgTTe'},
#       'href': 'https://api.spotify.com/v1/artists/0ZdCJB39o81l85QK7PgTTe',
#       'id': '0ZdCJB39o81l85QK7PgTTe',
#       'name': 'Willy Beaman',
#       'type': 'artist',
#       'uri': 'spotify:artist:0ZdCJB39o81l85QK7PgTTe'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/1HRIzEYLoNSJoKLjkQnUbe'},
#       'href': 'https://api.spotify.com/v1/artists/1HRIzEYLoNSJoKLjkQnUbe',
#       'id': '1HRIzEYLoNSJoKLjkQnUbe',
#       'name': 'Josh Wood',
#       'type': 'artist',
#       'uri': 'spotify:artist:1HRIzEYLoNSJoKLjkQnUbe'}],
#     'available_markets': ['DK', 'FI', 'IS', 'NO', 'SE'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/61MJ4uOuf01g8K1lnVX92Z'},
#     'href': 'https://api.spotify.com/v1/albums/61MJ4uOuf01g8K1lnVX92Z',
#     'id': '61MJ4uOuf01g8K1lnVX92Z',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2734f9e9918be3541f51f6ac2bd',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e024f9e9918be3541f51f6ac2bd',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048514f9e9918be3541f51f6ac2bd',
#       'width': 64}],
#     'name': "Trippin' (feat. Josh Wood)",
#     'release_date': '2021-05-28',
#     'release_date_precision': 'day',
#     'total_tracks': 1,
#     'type': 'album',
#     'uri': 'spotify:album:61MJ4uOuf01g8K1lnVX92Z'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0ZdCJB39o81l85QK7PgTTe'},
#      'href': 'https://api.spotify.com/v1/artists/0ZdCJB39o81l85QK7PgTTe',
#      'id': '0ZdCJB39o81l85QK7PgTTe',
#      'name': 'Willy Beaman',
#      'type': 'artist',
#      'uri': 'spotify:artist:0ZdCJB39o81l85QK7PgTTe'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/1HRIzEYLoNSJoKLjkQnUbe'},
#      'href': 'https://api.spotify.com/v1/artists/1HRIzEYLoNSJoKLjkQnUbe',
#      'id': '1HRIzEYLoNSJoKLjkQnUbe',
#      'name': 'Josh Wood',
#      'type': 'artist',
#      'uri': 'spotify:artist:1HRIzEYLoNSJoKLjkQnUbe'}],
#    'available_markets': ['DK', 'FI', 'IS', 'NO', 'SE'],
#    'disc_number': 1,
#    'duration_ms': 147670,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'DK4YA2140901'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/6jntbhQOjQSB1ABoqQxczp'},
#    'href': 'https://api.spotify.com/v1/tracks/6jntbhQOjQSB1ABoqQxczp',
#    'id': '6jntbhQOjQSB1ABoqQxczp',
#    'is_local': False,
#    'name': "Trippin' (feat. Josh Wood)",
#    'popularity': 34,
#    'preview_url': 'https://p.scdn.co/mp3-preview/b539cdc82a14ad1166e28e375f7a2be739e92221?cid=5a11aee182e7428bad8cfc351a5298ec',
#    'track': True,
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:6jntbhQOjQSB1ABoqQxczp'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2021-10-08T06:48:47Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/hbhz741mqsyfv0zafwby1nbq0'},
#    'href': 'https://api.spotify.com/v1/users/hbhz741mqsyfv0zafwby1nbq0',
#    'id': 'hbhz741mqsyfv0zafwby1nbq0',
#    'type': 'user',
#    'uri': 'spotify:user:hbhz741mqsyfv0zafwby1nbq0'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2TcGJdSOiOvITBzhvfX8XB'},
#       'href': 'https://api.spotify.com/v1/artists/2TcGJdSOiOvITBzhvfX8XB',
#       'id': '2TcGJdSOiOvITBzhvfX8XB',
#       'name': 'Shouse',
#       'type': 'artist',
#       'uri': 'spotify:artist:2TcGJdSOiOvITBzhvfX8XB'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/5KXv2MHeoLSqZ96jRuFF9H'},
#     'href': 'https://api.spotify.com/v1/albums/5KXv2MHeoLSqZ96jRuFF9H',
#     'id': '5KXv2MHeoLSqZ96jRuFF9H',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b27381376e47003d45f6513b5657',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e0281376e47003d45f6513b5657',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d0000485181376e47003d45f6513b5657',
#       'width': 64}],
#     'name': 'Love Tonight',
#     'release_date': '2017-12-14',
#     'release_date_precision': 'day',
#     'total_tracks': 2,
#     'type': 'album',
#     'uri': 'spotify:album:5KXv2MHeoLSqZ96jRuFF9H'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2TcGJdSOiOvITBzhvfX8XB'},
#      'href': 'https://api.spotify.com/v1/artists/2TcGJdSOiOvITBzhvfX8XB',
#      'id': '2TcGJdSOiOvITBzhvfX8XB',
#      'name': 'Shouse',
#      'type': 'artist',
#      'uri': 'spotify:artist:2TcGJdSOiOvITBzhvfX8XB'}],
#    'available_markets': ['AD',
#     'AE',
#     'AG',
#     'AL',
#     'AM',
#     'AO',
#     'AR',
#     'AT',
#     'AU',
#     'AZ',
#     'BA',
#     'BB',
#     'BD',
#     'BE',
#     'BF',
#     'BG',
#     'BH',
#     'BI',
#     'BJ',
#     'BN',
#     'BO',
#     'BR',
#     'BS',
#     'BT',
#     'BW',
#     'BY',
#     'BZ',
#     'CA',
#     'CH',
#     'CI',
#     'CL',
#     'CM',
#     'CO',
#     'CR',
#     'CV',
#     'CW',
#     'CY',
#     'CZ',
#     'DE',
#     'DJ',
#     'DK',
#     'DM',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FJ',
#     'FM',
#     'FR',
#     'GA',
#     'GB',
#     'GD',
#     'GE',
#     'GH',
#     'GM',
#     'GN',
#     'GQ',
#     'GR',
#     'GT',
#     'GW',
#     'GY',
#     'HK',
#     'HN',
#     'HR',
#     'HT',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JM',
#     'JO',
#     'JP',
#     'KE',
#     'KG',
#     'KH',
#     'KI',
#     'KM',
#     'KN',
#     'KR',
#     'KW',
#     'KZ',
#     'LA',
#     'LB',
#     'LC',
#     'LI',
#     'LK',
#     'LR',
#     'LS',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MG',
#     'MH',
#     'MK',
#     'ML',
#     'MN',
#     'MO',
#     'MR',
#     'MT',
#     'MU',
#     'MV',
#     'MW',
#     'MX',
#     'MY',
#     'MZ',
#     'NA',
#     'NE',
#     'NG',
#     'NI',
#     'NL',
#     'NO',
#     'NP',
#     'NR',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PG',
#     'PH',
#     'PK',
#     'PL',
#     'PS',
#     'PT',
#     'PW',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RU',
#     'RW',
#     'SA',
#     'SB',
#     'SC',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SL',
#     'SM',
#     'SN',
#     'SR',
#     'ST',
#     'SV',
#     'SZ',
#     'TD',
#     'TG',
#     'TH',
#     'TL',
#     'TN',
#     'TO',
#     'TR',
#     'TT',
#     'TV',
#     'TW',
#     'TZ',
#     'UA',
#     'UG',
#     'US',
#     'UY',
#     'UZ',
#     'VC',
#     'VN',
#     'VU',
#     'WS',
#     'XK',
#     'ZA',
#     'ZM',
#     'ZW'],
#    'disc_number': 1,
#    'duration_ms': 241970,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'USQY51798087'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/6OufwUcCqo81guU2jAlDVP'},
#    'href': 'https://api.spotify.com/v1/tracks/6OufwUcCqo81guU2jAlDVP',
#    'id': '6OufwUcCqo81guU2jAlDVP',
#    'is_local': False,
#    'name': 'Love Tonight - Edit',
#    'popularity': 88,
#    'preview_url': 'https://p.scdn.co/mp3-preview/1b325d885c74df69b510512823e199f78b6d651c?cid=5a11aee182e7428bad8cfc351a5298ec',
#    'track': True,
#    'track_number': 2,
#    'type': 'track',
#    'uri': 'spotify:track:6OufwUcCqo81guU2jAlDVP'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2021-10-08T06:48:47Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/hbhz741mqsyfv0zafwby1nbq0'},
#    'href': 'https://api.spotify.com/v1/users/hbhz741mqsyfv0zafwby1nbq0',
#    'id': 'hbhz741mqsyfv0zafwby1nbq0',
#    'type': 'user',
#    'uri': 'spotify:user:hbhz741mqsyfv0zafwby1nbq0'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0t2rVUFJxfR071gkSIwiCC'},
#       'href': 'https://api.spotify.com/v1/artists/0t2rVUFJxfR071gkSIwiCC',
#       'id': '0t2rVUFJxfR071gkSIwiCC',
#       'name': 'ZEXTONE',
#       'type': 'artist',
#       'uri': 'spotify:artist:0t2rVUFJxfR071gkSIwiCC'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/29yyPuky7khfsycbqK19uE'},
#       'href': 'https://api.spotify.com/v1/artists/29yyPuky7khfsycbqK19uE',
#       'id': '29yyPuky7khfsycbqK19uE',
#       'name': 'Victor Perry',
#       'type': 'artist',
#       'uri': 'spotify:artist:29yyPuky7khfsycbqK19uE'}],
#     'available_markets': ['DK', 'FI', 'IS', 'NO', 'SE'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/79ojaFRD7j0rmzYnvlxSyx'},
#     'href': 'https://api.spotify.com/v1/albums/79ojaFRD7j0rmzYnvlxSyx',
#     'id': '79ojaFRD7j0rmzYnvlxSyx',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273e2d7d82a4697d0aedac69916',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02e2d7d82a4697d0aedac69916',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851e2d7d82a4697d0aedac69916',
#       'width': 64}],
#     'name': 'Skinny Love',
#     'release_date': '2021-09-03',
#     'release_date_precision': 'day',
#     'total_tracks': 1,
#     'type': 'album',
#     'uri': 'spotify:album:79ojaFRD7j0rmzYnvlxSyx'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0t2rVUFJxfR071gkSIwiCC'},
#      'href': 'https://api.spotify.com/v1/artists/0t2rVUFJxfR071gkSIwiCC',
#      'id': '0t2rVUFJxfR071gkSIwiCC',
#      'name': 'ZEXTONE',
#      'type': 'artist',
#      'uri': 'spotify:artist:0t2rVUFJxfR071gkSIwiCC'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/29yyPuky7khfsycbqK19uE'},
#      'href': 'https://api.spotify.com/v1/artists/29yyPuky7khfsycbqK19uE',
#      'id': '29yyPuky7khfsycbqK19uE',
#      'name': 'Victor Perry',
#      'type': 'artist',
#      'uri': 'spotify:artist:29yyPuky7khfsycbqK19uE'}],
#    'available_markets': ['DK', 'FI', 'IS', 'NO', 'SE'],
#    'disc_number': 1,
#    'duration_ms': 176640,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'DK4YA2128001'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/4hB2TYKTggqdmZatKVO8La'},
#    'href': 'https://api.spotify.com/v1/tracks/4hB2TYKTggqdmZatKVO8La',
#    'id': '4hB2TYKTggqdmZatKVO8La',
#    'is_local': False,
#    'name': 'Skinny Love',
#    'popularity': 26,
#    'preview_url': 'https://p.scdn.co/mp3-preview/0bf3c6cd1a62ddd66c6aa8587fc2575c7ec1d220?cid=5a11aee182e7428bad8cfc351a5298ec',
#    'track': True,
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:4hB2TYKTggqdmZatKVO8La'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2021-10-08T06:48:47Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/hbhz741mqsyfv0zafwby1nbq0'},
#    'href': 'https://api.spotify.com/v1/users/hbhz741mqsyfv0zafwby1nbq0',
#    'id': 'hbhz741mqsyfv0zafwby1nbq0',
#    'type': 'user',
#    'uri': 'spotify:user:hbhz741mqsyfv0zafwby1nbq0'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0Nj6EN5mur7EJHl0aZuGP7'},
#       'href': 'https://api.spotify.com/v1/artists/0Nj6EN5mur7EJHl0aZuGP7',
#       'id': '0Nj6EN5mur7EJHl0aZuGP7',
#       'name': 'Vera',
#       'type': 'artist',
#       'uri': 'spotify:artist:0Nj6EN5mur7EJHl0aZuGP7'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/2pobDPwk9fuzujz5YKKAVB'},
#       'href': 'https://api.spotify.com/v1/artists/2pobDPwk9fuzujz5YKKAVB',
#       'id': '2pobDPwk9fuzujz5YKKAVB',
#       'name': 'Jada',
#       'type': 'artist',
#       'uri': 'spotify:artist:2pobDPwk9fuzujz5YKKAVB'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/5LZBrssVL7hhI9D4ibX2Oz'},
#     'href': 'https://api.spotify.com/v1/albums/5LZBrssVL7hhI9D4ibX2Oz',
#     'id': '5LZBrssVL7hhI9D4ibX2Oz',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273749bce67102b9cf59054842d',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02749bce67102b9cf59054842d',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851749bce67102b9cf59054842d',
#       'width': 64}],
#     'name': 'Lifetime (Chill Mix)',
#     'release_date': '2021-02-05',
#     'release_date_precision': 'day',
#     'total_tracks': 1,
#     'type': 'album',
#     'uri': 'spotify:album:5LZBrssVL7hhI9D4ibX2Oz'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0Nj6EN5mur7EJHl0aZuGP7'},
#      'href': 'https://api.spotify.com/v1/artists/0Nj6EN5mur7EJHl0aZuGP7',
#      'id': '0Nj6EN5mur7EJHl0aZuGP7',
#      'name': 'Vera',
#      'type': 'artist',
#      'uri': 'spotify:artist:0Nj6EN5mur7EJHl0aZuGP7'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/2pobDPwk9fuzujz5YKKAVB'},
#      'href': 'https://api.spotify.com/v1/artists/2pobDPwk9fuzujz5YKKAVB',
#      'id': '2pobDPwk9fuzujz5YKKAVB',
#      'name': 'Jada',
#      'type': 'artist',
#      'uri': 'spotify:artist:2pobDPwk9fuzujz5YKKAVB'}],
#    'available_markets': ['AD',
#     'AE',
#     'AG',
#     'AL',
#     'AM',
#     'AO',
#     'AR',
#     'AT',
#     'AU',
#     'AZ',
#     'BA',
#     'BB',
#     'BD',
#     'BE',
#     'BF',
#     'BG',
#     'BH',
#     'BI',
#     'BJ',
#     'BN',
#     'BO',
#     'BR',
#     'BS',
#     'BT',
#     'BW',
#     'BY',
#     'BZ',
#     'CA',
#     'CH',
#     'CI',
#     'CL',
#     'CM',
#     'CO',
#     'CR',
#     'CV',
#     'CW',
#     'CY',
#     'CZ',
#     'DE',
#     'DJ',
#     'DK',
#     'DM',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FJ',
#     'FM',
#     'FR',
#     'GA',
#     'GB',
#     'GD',
#     'GE',
#     'GH',
#     'GM',
#     'GN',
#     'GQ',
#     'GR',
#     'GT',
#     'GW',
#     'GY',
#     'HK',
#     'HN',
#     'HR',
#     'HT',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JM',
#     'JO',
#     'JP',
#     'KE',
#     'KG',
#     'KH',
#     'KI',
#     'KM',
#     'KN',
#     'KR',
#     'KW',
#     'KZ',
#     'LA',
#     'LB',
#     'LC',
#     'LI',
#     'LK',
#     'LR',
#     'LS',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MG',
#     'MH',
#     'MK',
#     'ML',
#     'MN',
#     'MO',
#     'MR',
#     'MT',
#     'MU',
#     'MV',
#     'MW',
#     'MX',
#     'MY',
#     'MZ',
#     'NA',
#     'NE',
#     'NG',
#     'NI',
#     'NL',
#     'NO',
#     'NP',
#     'NR',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PG',
#     'PH',
#     'PK',
#     'PL',
#     'PS',
#     'PT',
#     'PW',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RU',
#     'RW',
#     'SA',
#     'SB',
#     'SC',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SL',
#     'SM',
#     'SN',
#     'SR',
#     'ST',
#     'SV',
#     'SZ',
#     'TD',
#     'TG',
#     'TH',
#     'TL',
#     'TN',
#     'TO',
#     'TR',
#     'TT',
#     'TV',
#     'TW',
#     'TZ',
#     'UA',
#     'UG',
#     'US',
#     'UY',
#     'UZ',
#     'VC',
#     'VN',
#     'VU',
#     'WS',
#     'XK',
#     'ZA',
#     'ZM',
#     'ZW'],
#    'disc_number': 1,
#    'duration_ms': 201750,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'DK4YA2120201'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/26sNNFLwPBtWNgU34YvKcg'},
#    'href': 'https://api.spotify.com/v1/tracks/26sNNFLwPBtWNgU34YvKcg',
#    'id': '26sNNFLwPBtWNgU34YvKcg',
#    'is_local': False,
#    'name': 'Lifetime - Chill Mix',
#    'popularity': 52,
#    'preview_url': 'https://p.scdn.co/mp3-preview/8fe7e9126b305687a88e1afc9e732d0e7e1cb6fe?cid=5a11aee182e7428bad8cfc351a5298ec',
#    'track': True,
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:26sNNFLwPBtWNgU34YvKcg'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2021-10-08T06:48:47Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/hbhz741mqsyfv0zafwby1nbq0'},
#    'href': 'https://api.spotify.com/v1/users/hbhz741mqsyfv0zafwby1nbq0',
#    'id': 'hbhz741mqsyfv0zafwby1nbq0',
#    'type': 'user',
#    'uri': 'spotify:user:hbhz741mqsyfv0zafwby1nbq0'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6FU8aRDlZ8zAMjmi5PvT35'},
#       'href': 'https://api.spotify.com/v1/artists/6FU8aRDlZ8zAMjmi5PvT35',
#       'id': '6FU8aRDlZ8zAMjmi5PvT35',
#       'name': 'LVSN',
#       'type': 'artist',
#       'uri': 'spotify:artist:6FU8aRDlZ8zAMjmi5PvT35'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/6zFDmr6TUlLrZ3H2KQK0KA'},
#       'href': 'https://api.spotify.com/v1/artists/6zFDmr6TUlLrZ3H2KQK0KA',
#       'id': '6zFDmr6TUlLrZ3H2KQK0KA',
#       'name': 'LODE',
#       'type': 'artist',
#       'uri': 'spotify:artist:6zFDmr6TUlLrZ3H2KQK0KA'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/6bNnQIzGszCJgHI90SRt64'},
#       'href': 'https://api.spotify.com/v1/artists/6bNnQIzGszCJgHI90SRt64',
#       'id': '6bNnQIzGszCJgHI90SRt64',
#       'name': 'Young Jae',
#       'type': 'artist',
#       'uri': 'spotify:artist:6bNnQIzGszCJgHI90SRt64'}],
#     'available_markets': ['DK', 'FI', 'IS', 'NO', 'SE'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/0iMMRAGRTG2dCtuNaF57TZ'},
#     'href': 'https://api.spotify.com/v1/albums/0iMMRAGRTG2dCtuNaF57TZ',
#     'id': '0iMMRAGRTG2dCtuNaF57TZ',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273f3739b165b00e9f3e3e8b7bd',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02f3739b165b00e9f3e3e8b7bd',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851f3739b165b00e9f3e3e8b7bd',
#       'width': 64}],
#     'name': 'Dancing',
#     'release_date': '2021-09-10',
#     'release_date_precision': 'day',
#     'total_tracks': 1,
#     'type': 'album',
#     'uri': 'spotify:album:0iMMRAGRTG2dCtuNaF57TZ'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6FU8aRDlZ8zAMjmi5PvT35'},
#      'href': 'https://api.spotify.com/v1/artists/6FU8aRDlZ8zAMjmi5PvT35',
#      'id': '6FU8aRDlZ8zAMjmi5PvT35',
#      'name': 'LVSN',
#      'type': 'artist',
#      'uri': 'spotify:artist:6FU8aRDlZ8zAMjmi5PvT35'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/6zFDmr6TUlLrZ3H2KQK0KA'},
#      'href': 'https://api.spotify.com/v1/artists/6zFDmr6TUlLrZ3H2KQK0KA',
#      'id': '6zFDmr6TUlLrZ3H2KQK0KA',
#      'name': 'LODE',
#      'type': 'artist',
#      'uri': 'spotify:artist:6zFDmr6TUlLrZ3H2KQK0KA'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/6bNnQIzGszCJgHI90SRt64'},
#      'href': 'https://api.spotify.com/v1/artists/6bNnQIzGszCJgHI90SRt64',
#      'id': '6bNnQIzGszCJgHI90SRt64',
#      'name': 'Young Jae',
#      'type': 'artist',
#      'uri': 'spotify:artist:6bNnQIzGszCJgHI90SRt64'}],
#    'available_markets': ['DK', 'FI', 'IS', 'NO', 'SE'],
#    'disc_number': 1,
#    'duration_ms': 145121,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'DK4YA2151101'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/6W5Oca7EnKQZj6Ev8RS5Ly'},
#    'href': 'https://api.spotify.com/v1/tracks/6W5Oca7EnKQZj6Ev8RS5Ly',
#    'id': '6W5Oca7EnKQZj6Ev8RS5Ly',
#    'is_local': False,
#    'name': 'Dancing',
#    'popularity': 29,
#    'preview_url': 'https://p.scdn.co/mp3-preview/f2fbae6c2017d751f1db8b12062169b777401c45?cid=5a11aee182e7428bad8cfc351a5298ec',
#    'track': True,
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:6W5Oca7EnKQZj6Ev8RS5Ly'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2021-10-08T06:48:47Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/hbhz741mqsyfv0zafwby1nbq0'},
#    'href': 'https://api.spotify.com/v1/users/hbhz741mqsyfv0zafwby1nbq0',
#    'id': 'hbhz741mqsyfv0zafwby1nbq0',
#    'type': 'user',
#    'uri': 'spotify:user:hbhz741mqsyfv0zafwby1nbq0'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3xdxQ8fboHLHVfL9R4MvZ8'},
#       'href': 'https://api.spotify.com/v1/artists/3xdxQ8fboHLHVfL9R4MvZ8',
#       'id': '3xdxQ8fboHLHVfL9R4MvZ8',
#       'name': 'BOILERS',
#       'type': 'artist',
#       'uri': 'spotify:artist:3xdxQ8fboHLHVfL9R4MvZ8'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/6QACkIioo2Na2EKEwJzCKK'},
#       'href': 'https://api.spotify.com/v1/artists/6QACkIioo2Na2EKEwJzCKK',
#       'id': '6QACkIioo2Na2EKEwJzCKK',
#       'name': 'EC Twins',
#       'type': 'artist',
#       'uri': 'spotify:artist:6QACkIioo2Na2EKEwJzCKK'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/7MVtZkqiCMOWchZpXPEMXh'},
#       'href': 'https://api.spotify.com/v1/artists/7MVtZkqiCMOWchZpXPEMXh',
#       'id': '7MVtZkqiCMOWchZpXPEMXh',
#       'name': 'Gunnva',
#       'type': 'artist',
#       'uri': 'spotify:artist:7MVtZkqiCMOWchZpXPEMXh'}],
#     'available_markets': ['DK', 'FI', 'IS', 'NO', 'SE'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/6gWFOFLCJQ574fYgzRvq7s'},
#     'href': 'https://api.spotify.com/v1/albums/6gWFOFLCJQ574fYgzRvq7s',
#     'id': '6gWFOFLCJQ574fYgzRvq7s',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2738bead7d11e39b16c91c9a106',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e028bead7d11e39b16c91c9a106',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048518bead7d11e39b16c91c9a106',
#       'width': 64}],
#     'name': 'Runaway (U&I) (feat. Gunnva)',
#     'release_date': '2021-07-09',
#     'release_date_precision': 'day',
#     'total_tracks': 1,
#     'type': 'album',
#     'uri': 'spotify:album:6gWFOFLCJQ574fYgzRvq7s'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3xdxQ8fboHLHVfL9R4MvZ8'},
#      'href': 'https://api.spotify.com/v1/artists/3xdxQ8fboHLHVfL9R4MvZ8',
#      'id': '3xdxQ8fboHLHVfL9R4MvZ8',
#      'name': 'BOILERS',
#      'type': 'artist',
#      'uri': 'spotify:artist:3xdxQ8fboHLHVfL9R4MvZ8'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/6QACkIioo2Na2EKEwJzCKK'},
#      'href': 'https://api.spotify.com/v1/artists/6QACkIioo2Na2EKEwJzCKK',
#      'id': '6QACkIioo2Na2EKEwJzCKK',
#      'name': 'EC Twins',
#      'type': 'artist',
#      'uri': 'spotify:artist:6QACkIioo2Na2EKEwJzCKK'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/7MVtZkqiCMOWchZpXPEMXh'},
#      'href': 'https://api.spotify.com/v1/artists/7MVtZkqiCMOWchZpXPEMXh',
#      'id': '7MVtZkqiCMOWchZpXPEMXh',
#      'name': 'Gunnva',
#      'type': 'artist',
#      'uri': 'spotify:artist:7MVtZkqiCMOWchZpXPEMXh'}],
#    'available_markets': ['DK', 'FI', 'IS', 'NO', 'SE'],
#    'disc_number': 1,
#    'duration_ms': 160219,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'DK4YA2183001'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/6qdDNyIUWN6L6r5g2ah83K'},
#    'href': 'https://api.spotify.com/v1/tracks/6qdDNyIUWN6L6r5g2ah83K',
#    'id': '6qdDNyIUWN6L6r5g2ah83K',
#    'is_local': False,
#    'name': 'Runaway (U&I) (feat. Gunnva)',
#    'popularity': 32,
#    'preview_url': 'https://p.scdn.co/mp3-preview/b626e875608e5906d3a9911cf9872516eef0ced8?cid=5a11aee182e7428bad8cfc351a5298ec',
#    'track': True,
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:6qdDNyIUWN6L6r5g2ah83K'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2021-10-08T06:48:47Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/hbhz741mqsyfv0zafwby1nbq0'},
#    'href': 'https://api.spotify.com/v1/users/hbhz741mqsyfv0zafwby1nbq0',
#    'id': 'hbhz741mqsyfv0zafwby1nbq0',
#    'type': 'user',
#    'uri': 'spotify:user:hbhz741mqsyfv0zafwby1nbq0'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3PhoLpVuITZKcymswpck5b'},
#       'href': 'https://api.spotify.com/v1/artists/3PhoLpVuITZKcymswpck5b',
#       'id': '3PhoLpVuITZKcymswpck5b',
#       'name': 'Elton John',
#       'type': 'artist',
#       'uri': 'spotify:artist:3PhoLpVuITZKcymswpck5b'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/6M2wZ9GZgrQXHCFfjv46we'},
#       'href': 'https://api.spotify.com/v1/artists/6M2wZ9GZgrQXHCFfjv46we',
#       'id': '6M2wZ9GZgrQXHCFfjv46we',
#       'name': 'Dua Lipa',
#       'type': 'artist',
#       'uri': 'spotify:artist:6M2wZ9GZgrQXHCFfjv46we'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/6n28c9qs9hNGriNa72b26u'},
#       'href': 'https://api.spotify.com/v1/artists/6n28c9qs9hNGriNa72b26u',
#       'id': '6n28c9qs9hNGriNa72b26u',
#       'name': 'PNAU',
#       'type': 'artist',
#       'uri': 'spotify:artist:6n28c9qs9hNGriNa72b26u'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/5D8Rdb09BkmHscEGSWAlA6'},
#     'href': 'https://api.spotify.com/v1/albums/5D8Rdb09BkmHscEGSWAlA6',
#     'id': '5D8Rdb09BkmHscEGSWAlA6',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2739f5cce8304c42d3a5463fd23',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e029f5cce8304c42d3a5463fd23',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048519f5cce8304c42d3a5463fd23',
#       'width': 64}],
#     'name': 'Cold Heart (PNAU Remix)',
#     'release_date': '2021-08-13',
#     'release_date_precision': 'day',
#     'total_tracks': 1,
#     'type': 'album',
#     'uri': 'spotify:album:5D8Rdb09BkmHscEGSWAlA6'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3PhoLpVuITZKcymswpck5b'},
#      'href': 'https://api.spotify.com/v1/artists/3PhoLpVuITZKcymswpck5b',
#      'id': '3PhoLpVuITZKcymswpck5b',
#      'name': 'Elton John',
#      'type': 'artist',
#      'uri': 'spotify:artist:3PhoLpVuITZKcymswpck5b'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/6M2wZ9GZgrQXHCFfjv46we'},
#      'href': 'https://api.spotify.com/v1/artists/6M2wZ9GZgrQXHCFfjv46we',
#      'id': '6M2wZ9GZgrQXHCFfjv46we',
#      'name': 'Dua Lipa',
#      'type': 'artist',
#      'uri': 'spotify:artist:6M2wZ9GZgrQXHCFfjv46we'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/6n28c9qs9hNGriNa72b26u'},
#      'href': 'https://api.spotify.com/v1/artists/6n28c9qs9hNGriNa72b26u',
#      'id': '6n28c9qs9hNGriNa72b26u',
#      'name': 'PNAU',
#      'type': 'artist',
#      'uri': 'spotify:artist:6n28c9qs9hNGriNa72b26u'}],
#    'available_markets': ['AD',
#     'AE',
#     'AG',
#     'AL',
#     'AM',
#     'AO',
#     'AR',
#     'AT',
#     'AU',
#     'AZ',
#     'BA',
#     'BB',
#     'BD',
#     'BE',
#     'BF',
#     'BG',
#     'BH',
#     'BI',
#     'BJ',
#     'BN',
#     'BO',
#     'BR',
#     'BS',
#     'BT',
#     'BW',
#     'BY',
#     'BZ',
#     'CA',
#     'CH',
#     'CI',
#     'CL',
#     'CM',
#     'CO',
#     'CR',
#     'CV',
#     'CW',
#     'CY',
#     'CZ',
#     'DE',
#     'DJ',
#     'DK',
#     'DM',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FJ',
#     'FM',
#     'FR',
#     'GA',
#     'GB',
#     'GD',
#     'GE',
#     'GH',
#     'GM',
#     'GN',
#     'GQ',
#     'GR',
#     'GT',
#     'GW',
#     'GY',
#     'HK',
#     'HN',
#     'HR',
#     'HT',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JM',
#     'JO',
#     'JP',
#     'KE',
#     'KG',
#     'KH',
#     'KI',
#     'KM',
#     'KN',
#     'KR',
#     'KW',
#     'KZ',
#     'LA',
#     'LB',
#     'LC',
#     'LI',
#     'LK',
#     'LR',
#     'LS',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MG',
#     'MH',
#     'MK',
#     'ML',
#     'MN',
#     'MO',
#     'MR',
#     'MT',
#     'MU',
#     'MV',
#     'MW',
#     'MX',
#     'MY',
#     'MZ',
#     'NA',
#     'NE',
#     'NG',
#     'NI',
#     'NL',
#     'NO',
#     'NP',
#     'NR',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PG',
#     'PH',
#     'PK',
#     'PL',
#     'PS',
#     'PT',
#     'PW',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RU',
#     'RW',
#     'SA',
#     'SB',
#     'SC',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SL',
#     'SM',
#     'SN',
#     'SR',
#     'ST',
#     'SV',
#     'SZ',
#     'TD',
#     'TG',
#     'TH',
#     'TL',
#     'TN',
#     'TO',
#     'TR',
#     'TT',
#     'TV',
#     'TW',
#     'TZ',
#     'UA',
#     'UG',
#     'US',
#     'UY',
#     'UZ',
#     'VC',
#     'VN',
#     'VU',
#     'WS',
#     'XK',
#     'ZA',
#     'ZM',
#     'ZW'],
#    'disc_number': 1,
#    'duration_ms': 202735,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'GBUM72104705'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/6zSpb8dQRaw0M1dK8PBwQz'},
#    'href': 'https://api.spotify.com/v1/tracks/6zSpb8dQRaw0M1dK8PBwQz',
#    'id': '6zSpb8dQRaw0M1dK8PBwQz',
#    'is_local': False,
#    'name': 'Cold Heart - PNAU Remix',
#    'popularity': 93,
#    'preview_url': None,
#    'track': True,
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:6zSpb8dQRaw0M1dK8PBwQz'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2021-10-08T06:48:47Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/hbhz741mqsyfv0zafwby1nbq0'},
#    'href': 'https://api.spotify.com/v1/users/hbhz741mqsyfv0zafwby1nbq0',
#    'id': 'hbhz741mqsyfv0zafwby1nbq0',
#    'type': 'user',
# ...
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/3XXVoT0PDxroAX63FCLmwM'},
#     'href': 'https://api.spotify.com/v1/albums/3XXVoT0PDxroAX63FCLmwM',
#     'id': '3XXVoT0PDxroAX63FCLmwM',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273833c709ad23dac9810ec4671',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02833c709ad23dac9810ec4671',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851833c709ad23dac9810ec4671',
#       'width': 64}],
#     'name': 'Breakfast In America',
#     'release_date': '2019-08-16',
#     'release_date_precision': 'day',
#     'total_tracks': 1,
#     'type': 'album',
#     'uri': 'spotify:album:3XXVoT0PDxroAX63FCLmwM'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5UUdxfBMwm0hLlLgnZtBFv'},
#      'href': 'https://api.spotify.com/v1/artists/5UUdxfBMwm0hLlLgnZtBFv',
#      'id': '5UUdxfBMwm0hLlLgnZtBFv',
#      'name': 'Madism',
#      'type': 'artist',
#      'uri': 'spotify:artist:5UUdxfBMwm0hLlLgnZtBFv'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/2FMdAViOScZVhMjAunoYNK'},
#      'href': 'https://api.spotify.com/v1/artists/2FMdAViOScZVhMjAunoYNK',
#      'id': '2FMdAViOScZVhMjAunoYNK',
#      'name': 'Felix Samuel',
#      'type': 'artist',
#      'uri': 'spotify:artist:2FMdAViOScZVhMjAunoYNK'}],
#    'available_markets': ['AD',
#     'AE',
#     'AG',
#     'AL',
#     'AM',
#     'AO',
#     'AR',
#     'AT',
#     'AU',
#     'AZ',
#     'BA',
#     'BB',
#     'BD',
#     'BE',
#     'BF',
#     'BG',
#     'BH',
#     'BI',
#     'BJ',
#     'BN',
#     'BO',
#     'BR',
#     'BS',
#     'BT',
#     'BW',
#     'BY',
#     'BZ',
#     'CA',
#     'CH',
#     'CI',
#     'CL',
#     'CM',
#     'CO',
#     'CR',
#     'CV',
#     'CW',
#     'CY',
#     'CZ',
#     'DE',
#     'DJ',
#     'DK',
#     'DM',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FJ',
#     'FM',
#     'FR',
#     'GA',
#     'GB',
#     'GD',
#     'GE',
#     'GH',
#     'GM',
#     'GN',
#     'GQ',
#     'GR',
#     'GT',
#     'GW',
#     'GY',
#     'HK',
#     'HN',
#     'HR',
#     'HT',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JM',
#     'JO',
#     'JP',
#     'KE',
#     'KG',
#     'KH',
#     'KI',
#     'KM',
#     'KN',
#     'KR',
#     'KW',
#     'KZ',
#     'LA',
#     'LB',
#     'LC',
#     'LI',
#     'LK',
#     'LR',
#     'LS',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MG',
#     'MH',
#     'MK',
#     'ML',
#     'MN',
#     'MO',
#     'MR',
#     'MT',
#     'MU',
#     'MV',
#     'MW',
#     'MX',
#     'MY',
#     'MZ',
#     'NA',
#     'NE',
#     'NG',
#     'NI',
#     'NL',
#     'NO',
#     'NP',
#     'NR',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PG',
#     'PH',
#     'PK',
#     'PL',
#     'PS',
#     'PT',
#     'PW',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RU',
#     'RW',
#     'SA',
#     'SB',
#     'SC',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SL',
#     'SM',
#     'SN',
#     'SR',
#     'ST',
#     'SV',
#     'SZ',
#     'TD',
#     'TG',
#     'TH',
#     'TL',
#     'TN',
#     'TO',
#     'TR',
#     'TT',
#     'TV',
#     'TW',
#     'TZ',
#     'UA',
#     'UG',
#     'US',
#     'UY',
#     'UZ',
#     'VC',
#     'VN',
#     'VU',
#     'WS',
#     'XK',
#     'ZA',
#     'ZM',
#     'ZW'],
#    'disc_number': 1,
#    'duration_ms': 205860,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'DK4YA1914201'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/04c6EIZdGm0BYsw1lUUJcb'},
#    'href': 'https://api.spotify.com/v1/tracks/04c6EIZdGm0BYsw1lUUJcb',
#    'id': '04c6EIZdGm0BYsw1lUUJcb',
#    'is_local': False,
#    'name': 'Breakfast In America',
#    'popularity': 44,
#    'preview_url': 'https://p.scdn.co/mp3-preview/b27c053426b05e0796e31b719195a8b0430f1f33?cid=5a11aee182e7428bad8cfc351a5298ec',
#    'track': True,
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:04c6EIZdGm0BYsw1lUUJcb'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2021-10-08T06:48:47Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/hbhz741mqsyfv0zafwby1nbq0'},
#    'href': 'https://api.spotify.com/v1/users/hbhz741mqsyfv0zafwby1nbq0',
#    'id': 'hbhz741mqsyfv0zafwby1nbq0',
#    'type': 'user',
#    'uri': 'spotify:user:hbhz741mqsyfv0zafwby1nbq0'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7CajNmpbOovFoOoasH2HaY'},
#       'href': 'https://api.spotify.com/v1/artists/7CajNmpbOovFoOoasH2HaY',
#       'id': '7CajNmpbOovFoOoasH2HaY',
#       'name': 'Calvin Harris',
#       'type': 'artist',
#       'uri': 'spotify:artist:7CajNmpbOovFoOoasH2HaY'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/0dzeoQhVNzKkwM5ieOJC54'},
#     'href': 'https://api.spotify.com/v1/albums/0dzeoQhVNzKkwM5ieOJC54',
#     'id': '0dzeoQhVNzKkwM5ieOJC54',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2738d12bc5e3ea5c9f4a967de32',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e028d12bc5e3ea5c9f4a967de32',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048518d12bc5e3ea5c9f4a967de32',
#       'width': 64}],
#     'name': 'My Way',
#     'release_date': '2016-09-16',
#     'release_date_precision': 'day',
#     'total_tracks': 1,
#     'type': 'album',
#     'uri': 'spotify:album:0dzeoQhVNzKkwM5ieOJC54'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7CajNmpbOovFoOoasH2HaY'},
#      'href': 'https://api.spotify.com/v1/artists/7CajNmpbOovFoOoasH2HaY',
#      'id': '7CajNmpbOovFoOoasH2HaY',
#      'name': 'Calvin Harris',
#      'type': 'artist',
#      'uri': 'spotify:artist:7CajNmpbOovFoOoasH2HaY'}],
#    'available_markets': ['AD',
#     'AE',
#     'AG',
#     'AL',
#     'AM',
#     'AO',
#     'AR',
#     'AT',
#     'AU',
#     'AZ',
#     'BA',
#     'BB',
#     'BD',
#     'BE',
#     'BF',
#     'BG',
#     'BH',
#     'BI',
#     'BJ',
#     'BN',
#     'BO',
#     'BR',
#     'BS',
#     'BT',
#     'BW',
#     'BY',
#     'BZ',
#     'CA',
#     'CH',
#     'CI',
#     'CL',
#     'CM',
#     'CO',
#     'CR',
#     'CV',
#     'CW',
#     'CY',
#     'CZ',
#     'DE',
#     'DJ',
#     'DK',
#     'DM',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FJ',
#     'FM',
#     'FR',
#     'GA',
#     'GB',
#     'GD',
#     'GE',
#     'GH',
#     'GM',
#     'GN',
#     'GQ',
#     'GR',
#     'GT',
#     'GW',
#     'GY',
#     'HK',
#     'HN',
#     'HR',
#     'HT',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JM',
#     'JO',
#     'JP',
#     'KE',
#     'KG',
#     'KH',
#     'KI',
#     'KM',
#     'KN',
#     'KR',
#     'KW',
#     'KZ',
#     'LA',
#     'LB',
#     'LC',
#     'LI',
#     'LK',
#     'LR',
#     'LS',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MG',
#     'MH',
#     'MK',
#     'ML',
#     'MN',
#     'MO',
#     'MR',
#     'MT',
#     'MU',
#     'MV',
#     'MW',
#     'MX',
#     'MY',
#     'MZ',
#     'NA',
#     'NE',
#     'NG',
#     'NI',
#     'NL',
#     'NO',
#     'NP',
#     'NR',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PG',
#     'PH',
#     'PK',
#     'PL',
#     'PS',
#     'PT',
#     'PW',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RU',
#     'RW',
#     'SA',
#     'SB',
#     'SC',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SL',
#     'SM',
#     'SN',
#     'SR',
#     'ST',
#     'SV',
#     'SZ',
#     'TD',
#     'TG',
#     'TH',
#     'TL',
#     'TN',
#     'TO',
#     'TR',
#     'TT',
#     'TV',
#     'TW',
#     'TZ',
#     'UA',
#     'UG',
#     'US',
#     'UY',
#     'UZ',
#     'VC',
#     'VN',
#     'VU',
#     'WS',
#     'XK',
#     'ZA',
#     'ZM',
#     'ZW'],
#    'disc_number': 1,
#    'duration_ms': 219159,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'GBARL1601358'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/1vvNmPOiUuyCbgWmtc6yfm'},
#    'href': 'https://api.spotify.com/v1/tracks/1vvNmPOiUuyCbgWmtc6yfm',
#    'id': '1vvNmPOiUuyCbgWmtc6yfm',
#    'is_local': False,
#    'name': 'My Way',
#    'popularity': 75,
#    'preview_url': 'https://p.scdn.co/mp3-preview/574c5ea96188f94f779dbfca46cfd18c952e1761?cid=5a11aee182e7428bad8cfc351a5298ec',
#    'track': True,
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:1vvNmPOiUuyCbgWmtc6yfm'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2021-10-08T06:48:47Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/hbhz741mqsyfv0zafwby1nbq0'},
#    'href': 'https://api.spotify.com/v1/users/hbhz741mqsyfv0zafwby1nbq0',
#    'id': 'hbhz741mqsyfv0zafwby1nbq0',
#    'type': 'user',
#    'uri': 'spotify:user:hbhz741mqsyfv0zafwby1nbq0'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3MyFDtqB80WZvbtCZRsekM'},
#       'href': 'https://api.spotify.com/v1/artists/3MyFDtqB80WZvbtCZRsekM',
#       'id': '3MyFDtqB80WZvbtCZRsekM',
#       'name': 'Bakermat',
#       'type': 'artist',
#       'uri': 'spotify:artist:3MyFDtqB80WZvbtCZRsekM'}],
#     'available_markets': ['DK', 'EE', 'FI', 'IS', 'LT', 'LV', 'NO', 'SE'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/418vL0rOxoVcELcvu51fg9'},
#     'href': 'https://api.spotify.com/v1/albums/418vL0rOxoVcELcvu51fg9',
#     'id': '418vL0rOxoVcELcvu51fg9',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b27381cd4dea433cff9cccde9613',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e0281cd4dea433cff9cccde9613',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d0000485181cd4dea433cff9cccde9613',
#       'width': 64}],
#     'name': 'One Day (Vandaag)',
#     'release_date': '2014-03-28',
#     'release_date_precision': 'day',
#     'total_tracks': 1,
#     'type': 'album',
#     'uri': 'spotify:album:418vL0rOxoVcELcvu51fg9'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3MyFDtqB80WZvbtCZRsekM'},
#      'href': 'https://api.spotify.com/v1/artists/3MyFDtqB80WZvbtCZRsekM',
#      'id': '3MyFDtqB80WZvbtCZRsekM',
#      'name': 'Bakermat',
#      'type': 'artist',
#      'uri': 'spotify:artist:3MyFDtqB80WZvbtCZRsekM'}],
#    'available_markets': ['DK', 'EE', 'FI', 'IS', 'LT', 'LV', 'NO', 'SE'],
#    'disc_number': 1,
#    'duration_ms': 221013,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'DEE861400079'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/7qRtIcMaDnaJYmQDPpMgTe'},
#    'href': 'https://api.spotify.com/v1/tracks/7qRtIcMaDnaJYmQDPpMgTe',
#    'id': '7qRtIcMaDnaJYmQDPpMgTe',
#    'is_local': False,
#    'name': 'One Day (Vandaag) - Radio Edit',
#    'popularity': 45,
#    'preview_url': 'https://p.scdn.co/mp3-preview/d21208219b5d6ac71595a041bf9982650a2407cd?cid=5a11aee182e7428bad8cfc351a5298ec',
#    'track': True,
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:7qRtIcMaDnaJYmQDPpMgTe'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2021-10-08T06:48:47Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/hbhz741mqsyfv0zafwby1nbq0'},
#    'href': 'https://api.spotify.com/v1/users/hbhz741mqsyfv0zafwby1nbq0',
#    'id': 'hbhz741mqsyfv0zafwby1nbq0',
#    'type': 'user',
#    'uri': 'spotify:user:hbhz741mqsyfv0zafwby1nbq0'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2IjiuEObrCKyZvSb8xLxG9'},
#       'href': 'https://api.spotify.com/v1/artists/2IjiuEObrCKyZvSb8xLxG9',
#       'id': '2IjiuEObrCKyZvSb8xLxG9',
#       'name': 'filous',
#       'type': 'artist',
#       'uri': 'spotify:artist:2IjiuEObrCKyZvSb8xLxG9'}],
#     'available_markets': [],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/6cvHoxaW0RCXQMC5xQyAXF'},
#     'href': 'https://api.spotify.com/v1/albums/6cvHoxaW0RCXQMC5xQyAXF',
#     'id': '6cvHoxaW0RCXQMC5xQyAXF',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2733d192d39139d258a313761b2',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e023d192d39139d258a313761b2',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048513d192d39139d258a313761b2',
#       'width': 64}],
#     'name': 'How Hard I Try (feat. James Hersey)',
#     'release_date': '2015-05-26',
#     'release_date_precision': 'day',
#     'total_tracks': 1,
#     'type': 'album',
#     'uri': 'spotify:album:6cvHoxaW0RCXQMC5xQyAXF'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2IjiuEObrCKyZvSb8xLxG9'},
#      'href': 'https://api.spotify.com/v1/artists/2IjiuEObrCKyZvSb8xLxG9',
#      'id': '2IjiuEObrCKyZvSb8xLxG9',
#      'name': 'filous',
#      'type': 'artist',
#      'uri': 'spotify:artist:2IjiuEObrCKyZvSb8xLxG9'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/0lzV2CiahHRiGd6qpADtPS'},
#      'href': 'https://api.spotify.com/v1/artists/0lzV2CiahHRiGd6qpADtPS',
#      'id': '0lzV2CiahHRiGd6qpADtPS',
#      'name': 'James Hersey',
#      'type': 'artist',
#      'uri': 'spotify:artist:0lzV2CiahHRiGd6qpADtPS'}],
#    'available_markets': [],
#    'disc_number': 1,
#    'duration_ms': 198000,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'USUS11203409'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/7uzudGwu8EG5deuFD7EEJm'},
#    'href': 'https://api.spotify.com/v1/tracks/7uzudGwu8EG5deuFD7EEJm',
#    'id': '7uzudGwu8EG5deuFD7EEJm',
#    'is_local': False,
#    'name': 'How Hard I Try (feat. James Hersey)',
#    'popularity': 3,
#    'preview_url': None,
#    'track': True,
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:7uzudGwu8EG5deuFD7EEJm'},
#   'video_thumbnail': {'url': None}}]

# %%
def get_playlist_tracks(username, playlist_id):
    
    results = sp.user_playlist_tracks(username, playlist_id)
    tracks = results['items']
    
    while results['next']:
        results = sp.next(results)
        tracks.extend(results['items'])
    
    return tracks

# %%
def get_artists_from_playlist(playlist_id):
    
    tracks_from_playlist = get_playlist_tracks("spotify", playlist_id)
    
    artists = []
    
    for track in tracks_from_playlist:
        artists_info = track['track']['artists']
        
        for artist_info in artists_info:
            artists.append(artist_info['name'])
    
    return list(set(artists))

# %%
def get_artists_ids_from_playlist(playlist_id):
    
    tracks_from_playlist = get_playlist_tracks("spotify", playlist_id)
    
    artists_ids = []
    
    for track in tracks_from_playlist:
        artists_info = track['track']['artists']
        
        for artist_info in artists_info:
            artists_ids.append(artist_info['id'])
            
    return list(set(artists_ids))

# %%
artists = get_artists_from_playlist("4SAp2pqkCTYnu3midNetQ7")
artists
# Out:
# ['Vintage Culture',
#  'Courtney Drummey',
#  'Camilia',
#  'Alok',
#  'Nomcebo Zikode',
#  'Feb',
#  'Willy Beaman',
#  'Gunnva',
#  'RAYE',
#  'Lost Boy',
#  'Elton John',
#  'Nathan Goshen',
#  'Kid On The Block',
#  'SUD',
#  'Imanbek',
#  'Paolo Pellegrino',
#  'SOOBE',
#  'Dmitry Ko',
#  'Pedro Carrilho',
#  'Afrojack',
#  'BNNYZ',
#  'Dani Lima',
#  'A7S',
#  'Rock Da Cat',
#  'Brittany Foster',
#  'Michael Ford',
#  'Samuel Rhein',
#  'Able Faces',
#  'Jaydan Wolf',
#  'Rivo',
#  'Vi Anabella Kara',
#  'Zeeba',
#  'Polina Vita',
#  'Eduarda Aragão',
#  'Gabry Ponte',
#  'Young Jae',
#  'SICKWENZ',
#  'Framed Stories',
#  'Nathan Sinclair',
#  'Miles Hi',
#  'Duncan Townsend',
#  'Ayli',
#  'Lucky Luke',
#  'USAI',
#  'Josh Wood',
#  'ODEE',
#  'Fly By Midnight',
#  'Martin Jensen',
#  'Ian Storm',
#  'Koa',
#  'Tiësto',
#  'Paige',
#  'Madism',
#  'Firevibe',
#  'Matt Simons',
#  'NEIMY',
#  'James Hersey',
#  'Vera',
#  'Marcos Zeeba',
#  'Georgia Mos',
#  'Syrenne',
#  'Beemow',
#  'Lost Frequencies',
#  'Giiants',
#  'SOMMERS (UK)',
#  'Nicholas Roy',
#  'PNAU',
#  'MEDUZA',
#  'Matvey Emerson',
#  'Steve Forest',
#  'Dasco',
#  'Tobtok',
#  'Nick Amstok',
#  'Mastik Lickers',
#  'Deniz Koyu',
#  'Roiyal',
#  'Syon',
#  'Kevin Palms',
#  'James Arthur',
#  'Emelie Cyréus',
#  'Sam Luck',
#  'Jack Wins',
#  'Alex Hosking',
#  'The Crushboys',
#  'ZEXTONE',
#  'Émilie Rachel',
#  'Victor Perry',
#  'Regard',
#  'Benlon',
#  'Plastik Funk',
#  'Kungs',
#  'Kups',
#  'Jada',
#  'EC Twins',
#  'Sam Welch',
#  'Jules Kyng',
#  'Burak Yeter',
#  'AINT',
#  'KVR',
#  'SOMMA',
#  'Mougleta',
#  'Viva La Panda',
#  'BOILERS',
#  'CILVR',
#  'Alessia Labate',
#  'Idle Days',
#  'Pansil',
#  'Harrison',
#  'ZAPOLYA',
#  'Jay Mason',
#  'Britt Lari',
#  'Maverick Sabre',
#  'Rond Louis Smith 2nd',
#  'Dennis Lloyd',
#  'Jorja Smith',
#  'KALUMA',
#  'Haasy',
#  'ESound',
#  'Möwe',
#  'Slow Motion',
#  'Alle Farben',
#  'Hartzon',
#  'EMDI',
#  'GABRIEL IXEA',
#  'De Hofnar',
#  'Tim Bell',
#  'WISEKIDS',
#  'Rudimental',
#  'filous',
#  'Purple Disco Machine',
#  'Below The Radar',
#  'Eskeemo',
#  'The High',
#  'Erlando',
#  'Sick Individuals',
#  'MÏETI',
#  'Gaullin',
#  'Ynnox',
#  'Bless You',
#  'Dermot Kennedy',
#  'Stephanie Schulte',
#  'Katy Tiz',
#  'MOLOW',
#  'Dave Crusher',
#  'Zonderling',
#  'Capital People',
#  'TOM SOTO',
#  'AHB',
#  'Blinkie',
#  'Shibui',
#  "Cookin' On 3 Burners",
#  'Jubël',
#  'FAST BOY',
#  'Tim Grand',
#  'R3YAN',
#  'Jonasu',
#  'Luca Schreiner',
#  'Olive',
#  'Karma Child',
#  'StolenKidz',
#  'Johnny Balik',
#  'Oxen Butcher',
#  'Bakermat',
#  'Theresa Rex',
#  'Topic',
#  'Aman Saeed',
#  'James Carter',
#  'Menno',
#  'Bertie Scott',
#  'Master KG',
#  'Galwaro',
#  'Pedro Cazanova',
#  'Ron van den Beuken',
#  'Tom Enzy',
#  'TRIBE TONEZ',
#  'Buzz Low',
#  'coastkid',
#  'Richard Judge',
#  'Zwette',
#  'LVSN',
#  'Cladigal',
#  'offrami',
#  'Avicii',
#  'DJ Frog',
#  'Sabrina Deep',
#  'River',
#  'Nicola Fasano',
#  'Felix Samuel',
#  'Goodboys',
#  'Dillistone',
#  'Nick Martin',
#  'Calum Scott',
#  'Mr. Probz',
#  'C-Ro',
#  'Rhionn Maxwell',
#  'Tate McRae',
#  'Nathaniel',
#  'Future Friends',
#  'Nippandab',
#  'Divolly & Markward',
#  'Nea',
#  'Becky Hill',
#  'Bruno Martini',
#  'Nightcall',
#  'Mary Leay',
#  'Calum Venice',
#  'Discofields',
#  'Danelle Sandoval',
#  'Sebastien Dior',
#  'Samuel Gajicki',
#  'ManyFew',
#  'Dimitri Vegas & Like Mike',
#  'Dayna Madison',
#  'Shouse',
#  'Sophie and the Giants',
#  'TOOMANYLEFTHANDS',
#  'Felix Jaehn',
#  'M A I S Ø N',
#  'Gia Koka',
#  'Dua Lipa',
#  'Chumash',
#  'Calvin Harris',
#  'Teddy Beats',
#  'HUTS',
#  'NRONE',
#  'Aloe Blacc',
#  'MAYLYN',
#  'Cape Cub',
#  'LODE',
#  'Robin Schulz',
#  'Dimitri Vegas',
#  'Bayza']

# %%
artists_id = get_artists_ids_from_playlist("4SAp2pqkCTYnu3midNetQ7")
artists_id
# Out:
# ['656ibQgcoUQrUPdhQWRcI3',
#  '74BZ0Gsi15akr1wfifTfHs',
#  '0lFLwxM5lPGtJVmCkjYTQ3',
#  '3epmauRv4DCTZhwWLmgbS5',
#  '6c1KIrxttQDU6A31FwNlXg',
#  '2E19mfEFhCr6UgZUYJGOEW',
#  '55zK8WpUcGbdvtU7Apjeb7',
#  '5KKpBU5eC2tJDzf0wmlRp2',
#  '0ZdCJB39o81l85QK7PgTTe',
#  '0NGAZxHanS9e0iNHpR8f2W',
#  '3YTanNj4hKe9S5RJXNIpG0',
#  '0Ofkz1IWG2cp9ieI5PtW9u',
#  '7keGfmQR4X5w0two1xKZ7d',
#  '4Zv4yFnzY2v8IE2Fo0pqY8',
#  '733pYGuQ9xwCh15uK2VWT1',
#  '6VlE82AXyZhHEo87D6C1RH',
#  '5ee4yhrWOxaxvL77BoVpVR',
#  '0ztZKDB7Hlgn788xkCSeXt',
#  '5s7hwju24qO7raJrUEYsON',
#  '33W1pnW9zScZtYTnAoWnOT',
#  '6eNhhKFo3IUwCPKsciNHzp',
#  '7Dz9goFmVZZqvJxZoKg7pF',
#  '4n7LqAJhu3k6rrKMu3VfDa',
#  '4gmndqcVVyxmzgOunTiuAD',
#  '0nJcDqY6ox4kHB92AuRA8j',
#  '5fiYAV2DWASxAUKDq7Gbe9',
#  '4sF2Kkq3hn0yTEGTNfanGl',
#  '7nqlScm2smydSRl13eaP8E',
#  '3znJOYi3CDM5ZQkbo6kmjd',
#  '6jmHuLfbWlq34KedQ7mA5I',
#  '6thT1by4MprLKxnVYtqQik',
#  '4ehtJnVumNf6xzSCDk8aLB',
#  '6sWSaBb5ToNwrlsPBtKWhN',
#  '29yyPuky7khfsycbqK19uE',
#  '0nKVNSeqsoH9x6dHFjX1lX',
#  '2o5jDhtHVPhrJdv3cEQ99Z',
#  '0L57c1GtgWcYzJ7fvgBIBE',
#  '0AJ9YvsEOnAqMB9Q15TfYQ',
#  '5bBKSut3KtxJFIgxC4iS7o',
#  '4EPJlUEBy49EX1wuFOvtjK',
#  '1CoZyIx7UvdxT5c8UkMzHd',
#  '5IuugmUXbSoEUqwwUA7Fxt',
#  '2CkqcLoo2rhbO8GLRVZika',
#  '4S8NmgM7oJ188sKp1waZpy',
#  '6fllSzvyC7OruOFZisOELq',
#  '6bNnQIzGszCJgHI90SRt64',
#  '7ErksWhMMsmGtgT1l1e159',
#  '5z275L9haKWG328mm7UFd3',
#  '6J2749jPHYhAZUq79rsNi0',
#  '1ltLaFy2ifgpIhjzYFsPw2',
#  '2m0xNVRx1tAHY3pfNXt7Ro',
#  '3BlrsOmVTIgSFRN23rmkHM',
#  '0bMKf3lIYR9GaNTdFKkTOr',
#  '3t5xRXzsuZmMDkQzgOX35S',
#  '7eKtGS8Huzy0vi0KVmNfqE',
#  '38aAEKHAmZwECZgFuUfdCB',
#  '6QNICF5q9tAnaEMcm3Sa79',
#  '1wL5NG5MAX6403vdsJGYME',
#  '1LFGVkNRmXz8jIkyPjaGNL',
#  '1Z0ioG8lmdE4sFZ8NDCNbJ',
#  '4IWBUUAFIplrNtaOHcJPRM',
#  '7ypPN35cJ9wfF2Zs7aYS33',
#  '4v0WD4FQ8lDk6lcKR5IATN',
#  '7ecUintnJKHsDyZT1qOPYZ',
#  '065CIh04vGvJ7FDpqrlWGZ',
#  '61ipISvUVa5LkJlKZnm3Oo',
#  '6M2wZ9GZgrQXHCFfjv46we',
#  '4xbJS00sHh5wBd5nYgsk8z',
#  '2jVMJy8BDrGD2Avxa4fH6q',
#  '39PhMWg1aAuuZcph0OXGu6',
#  '4bL2B6hmLlMWnUEZnorEtG',
#  '0id62QV2SZZfvBn9xpmuCl',
#  '6d4AePmkVnbu2qIbT6vsem',
#  '0jPFnkOW02ogcNH6PWnhUT',
#  '3ewQZ4iDkC9CQzceitueXe',
#  '13AFo4856ytys2f6kQqAlY',
#  '6rSNhHNlupYXbMe641ojqJ',
#  '70s3IS6gQEe8f9l08yYdpJ',
#  '0hxIhtwCpZU2Z9bDXc4dCk',
#  '1ZXJ2W76oJTt9OOjE1qInf',
#  '0xRXCcSX89eobfrshSVdyu',
#  '726MxZBpkxnnoKl6aN7mmj',
#  '2FMdAViOScZVhMjAunoYNK',
#  '0XqFDQJjqW5PfhfBCb53LR',
#  '3xdxQ8fboHLHVfL9R4MvZ8',
#  '1rbkX4vzWmG20XmG7DP73N',
#  '4mkCUH10teB1zbDohwQM8R',
#  '6zFDmr6TUlLrZ3H2KQK0KA',
#  '58O8UPrTdl4u2buM0skj94',
#  '4d4czVhvwZ2vTH0fdsoSVF',
#  '4PRItSqasFLl62nmQVBq0C',
#  '4u4pBjsrswz2nFyd0rClNw',
#  '1aQwKFn00nswXRDUDipm0K',
#  '3X2bWmlO8Oq7dIeEgAbTAB',
#  '4BThBqcTzRGFRvbddMykk7',
#  '6dNq1m9FnNCqSvRa70jwo3',
#  '4yURwmb56ISSxwTu6G0hvY',
#  '6lc0muqqPZVQsaTsNCyuRa',
#  '2Mb6xKUfphTNZ7PiDudasm',
#  '0nGAfMW3NzKeoFbNbq2N2s',
#  '6cmL8CNoQQKRMGHpuSqXcv',
#  '5cuIDrzlgb5jGwLlRWYnAc',
#  '0u6GtibW46tFX7koQ6uNJZ',
#  '4cfKtwkefMW3aiXtxfw8w6',
#  '0UFz5jBFwlNKaq1JwESYnX',
#  '6n28c9qs9hNGriNa72b26u',
#  '1MPTYMphF5G5cdiATErmvM',
#  '58jQ9ySMbgsPyB4VkDjGrQ',
#  '7MVtZkqiCMOWchZpXPEMXh',
#  '1HRIzEYLoNSJoKLjkQnUbe',
#  '6wx2DYiNYOG3HGQYQSBb9j',
#  '7CyfxnDxQiq8wjfS7dNCwE',
#  '4bTth1ur0qKM60o2f5kEXU',
#  '0YFOK5sYNqbCJEgD0xOti9',
#  '6cXU3B0U7wNEOOU8UjaWww',
#  '7wmCy21VjfmbP8DznMJe8v',
#  '5344K3N7rx7kw1HjO8psuq',
#  '6lbwPTGtzZrUWmc7sWLf7l',
#  '28uJnu5EsrGml2tBd7y8ts',
#  '3DgZk9TPxWee4QgbRpKGF4',
#  '5uCTOJnOeOAjPPRr5TnICA',
#  '2WBJQGf1bT1kxuoqziH5g4',
#  '3MyFDtqB80WZvbtCZRsekM',
#  '45dkTj5sMRSjrmBSBeiHym',
#  '7nL523vzwv24ad0oFf2VZ2',
#  '71WExccCBN2mw0klSzfYzz',
#  '36L4aidPfPFcI1KPY1XDFM',
#  '3xFkHylXN9yHzwCQBypRFn',
#  '3PhoLpVuITZKcymswpck5b',
#  '0pxkbA5HKBZkMyqyhINQqd',
#  '4Z99ysbztLlZqmYK3urV7w',
#  '5SZUMeZ1O9tcgkSkkx1dFy',
#  '2nm38smINjms1LtczR0Cei',
#  '6pcxIOhQCNb7DX2iuEXgxL',
#  '1qBdIvxju8AHbU7Zes7yF7',
#  '54c912G25eEURRdyPfcqIH',
#  '0lwuNJOYxPQQW0elJnlO5T',
#  '4FcZfItjVIsfO9TynErl7X',
#  '5KNNVgR6LBIABRIomyCwKJ',
#  '1K3qQyjoT9sA79KNExuzGC',
#  '2pobDPwk9fuzujz5YKKAVB',
#  '27bvypIhgG2n2j6ggHWf4E',
#  '0t2rVUFJxfR071gkSIwiCC',
#  '523y9KSneKh6APd1hKxLuF',
#  '0TAuJxwBthBIdrsm8wWJ0s',
#  '6QACkIioo2Na2EKEwJzCKK',
#  '5v8ZROs9c26k4yGMxUkebt',
#  '66uT5tPq9g2tO0qD43xCYq',
#  '4lIDPBFA9Umj1GrLVec2Vq',
#  '495JzkPWUCyhbtB8fPVb4Z',
#  '6oRmvag0pQojcoSnLNsZel',
#  '28E36JWtZHSjaWmKurU4x6',
#  '0dS5IlInNc5Qq0wIrFTKob',
#  '6xolTfoP9iAYak6NtI6xIV',
#  '34CKwqM4HBrBSMDRkJkHFl',
#  '6PAunVzpRKDn5xbMgkV1gh',
#  '6ydoSd3N2mwgwBHtF6K7eX',
#  '6FU8aRDlZ8zAMjmi5PvT35',
#  '6Nva7JhU0nL9SZ8ZvJni6O',
#  '4Al2E6xDgBDr3XUZn2t2ti',
#  '5UUdxfBMwm0hLlLgnZtBFv',
#  '5CXvT1JutlWVLJN8YEOf1h',
#  '3Ob3LAFJZDPtHa7675TPb2',
#  '71Dhj822M1LGpuryPIV2KO',
#  '6OXzciYkZCsfLnechSnFR2',
#  '5BVku7Olml0ffWJU8OWFek',
#  '4ON1ruy5ijE7ZPQthbrkgI',
#  '41Bz5o8M5l4QarFJfMJYsV',
#  '6pAN3oRUCzV7C5qVZpTBXT',
#  '0U6suWTdf1eQtxorBi2Chu',
#  '4rQTEdG6hDVOlDUFKs9EjZ',
#  '4vvTgPsYummtyhwm1N1dCj',
#  '7CajNmpbOovFoOoasH2HaY',
#  '1vCWHaC5f2uS3yhpwWbIA6',
#  '2URl3RyFpTbuZSa8AhZLGt',
#  '3JmD9HEyTy3vtITvwUFK9K',
#  '7qVyaRDqZ0T20SW7l1VzMX',
#  '1KSipyvbF74n5FigemQcFw',
#  '4D75GcNG95ebPtNvoNVXhz',
#  '2C0Cu6wbLYQyXl8MDwH2JE',
#  '56Qz2XwGj7FxnNKrfkWjnb',
#  '7mYKtiyBOIQ76RRRrb2I5f',
#  '2HkAI0YrEcgoR8QdaURqhO',
#  '7f5Zgnp2spUuuzKplmRkt7',
#  '0tytC9SBvhGJFUA0MPHucY',
#  '0Nj6EN5mur7EJHl0aZuGP7',
#  '7oZdp9UWjuC68LeJSYeKZL',
#  '5vgh47byX55s6GPztw1V3Q',
#  '4dgLZMavMm3danubiJxbtw',
#  '490J5Vpo8LblXIgwvrL3CG',
#  '2VD7hi5KkmTgalaFZ8dnls',
#  '3wwdmSpS097lVlr8fqSfnv',
#  '1TgPKG2Y9MClbu3Y1NgqP3',
#  '5veVxxPm1vzgi6pO2iVA8L',
#  '1qCOuZrrHQWQQpEBqLJhwN',
#  '2IjiuEObrCKyZvSb8xLxG9',
#  '12Br190pgwwhEjMY1ResUN',
#  '6Yti5KSZWOxrpOX9w8qAz0',
#  '0XuJdLNHkGkE2V0PfbCvYj',
#  '7qPLO2XOUaRrRxkvLZ3AEK',
#  '4FrXHrpbDLNyO3pbVv8RmF',
#  '3vDh2Mern1I2k53Oy0pDlD',
#  '6CEFAXiSvUDVs26MPyic13',
#  '73jBynjsVtofjRpdpRAJGk',
#  '0dVynfd4hdMUUaTcejaZZB',
#  '0ukgrNYk51TkMQr0f2Br4Q',
#  '1g0fXhQMHAxlRyIBkCbuE7',
#  '3DhhM9P7FHNRCHW0kx62zK',
#  '2B9KoDZvlZFCsHhmWCnWG4',
#  '4hn1lECUqPNvpm7wKgQ0HD',
#  '0lXF2cCg1bzrguJVr4GhqO',
#  '5rGrDvrLOV2VV8SCFVGWlj',
#  '58NOd3nTpJVVGma4x975P0',
#  '4ofCBoyEiGSePFAG500xev',
#  '4WN5naL3ofxrVBgFpguzKo',
#  '3EOEK57CV77D4ovYVcmiyt',
#  '7u4ayw4QFEsolPxZgnPAMT',
#  '0sbkGGlLYmgOzcxRqd257O',
#  '2A0sY7UDhv5v4hjvrhTlya',
#  '6UI6PW7WI2jz4SF5xllpgI',
#  '5Wg2b4Mp42gicxEeDNawf7',
#  '6eeppOTlVfh8p7NDyEZqUw',
#  '23TjYnUK2xGyalo5ABFV5F',
#  '5ENS85nZShljwNgg4wFD7D',
#  '6qYgKlSMSUj2DbN1bR1KcR',
#  '0lzV2CiahHRiGd6qpADtPS',
#  '5mKNjpx3SmjNqtxQTmuo9Z',
#  '6t9tbRO9Lv6Oq6xtVwfdrn',
#  '2TcGJdSOiOvITBzhvfX8XB',
#  '65qsLA8I7onvkxmmRz8sz9',
#  '5YCU9eHY4IYTyNa8XRFuw9',
#  '5tCPpDoXfTKy5yTongtDAT']

# %%
track_list=tracks.copy()

# %%
len(track_list)
# Out:
# 141

# %%
for i in artists_id:
    x = sp.artist_top_tracks(i)
    track_list.extend(x)

# %%
len(track_list)
# Out:
# 373
