# %% [markdown]
# # Lab | API wrappers - Create your collection of songs & audio features

# %% [markdown]
# #### To move forward with the project, you need to create a collection of songs with their audio features - as large as possible!

# %% [markdown]
# #### And, later, when the user inputs a song, we will find the cluster to which the song belongs and recommend a song from the same cluster. The more songs you have, the more accurate and diverse recommendations you'll be able to give. Although... you might want to make sure the collected songs are "curated" in a certain way. Try to find playlists of songs that are diverse, but also that meet certain standards.

# %% [markdown]
# #### An idea for collecting as many songs as possible is to start with all the songs of a big, diverse playlist and then go to every artist present in the playlist and grab every song of every album of that artist. The amount of songs you'll be collecting per playlist will grow exponentially!

# %%
import json
import pandas as pd

import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

# %%
sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id="cf245f23e4a6465d816f3d4b131c8dcd",
                                                           client_secret="935649211d1b4698bdda1fe65e7dd205"))

# %%
results = sp.user_playlist_tracks("spotify", "38wkMV0C3k4ldgRZ1mVW7H")
tracks = results['items']

# %%
for oset in range(100, results['total'],100):
    results = sp.user_playlist_tracks("spotify", "38wkMV0C3k4ldgRZ1mVW7H", offset=oset)
    tracks += results['items']
len(tracks)
# Out:
# 288

# %%
def get_playlist_tracks(username, playlist_id):
    
    results = sp.user_playlist_tracks(username, playlist_id)
    tracks = results['items']
    
    while results['next']:
        results = sp.next(results)
        tracks.extend(results['items'])
    
    return tracks

tracks = get_playlist_tracks("spotify", "38wkMV0C3k4ldgRZ1mVW7H")

# %%
# Getting all the artists

def get_artists_from_playlist(playlist_id):
    
    tracks_from_playlist = get_playlist_tracks("spotify", playlist_id)
    
    artists = []
    
    for track in tracks_from_playlist:
        artists_info = track['track']['artists']
        
        for artist_info in artists_info:
            artists.append(artist_info['name'])
    
    return list(set(artists))

# %%
# Getting all the artists IDs

def get_artists_ids_from_playlist(playlist_id):
    
    tracks_from_playlist = get_playlist_tracks("spotify", playlist_id)
    
    artists_ids = []
    
    for track in tracks_from_playlist:
        artists_info = track['track']['artists']
        
        for artist_info in artists_info:
            artists_ids.append(artist_info['id'])
            
    return list(set(artists_ids))

# %%
artists = get_artists_from_playlist("38wkMV0C3k4ldgRZ1mVW7H")

# %%
artists_ids = get_artists_ids_from_playlist("38wkMV0C3k4ldgRZ1mVW7H")

# %%
playlist_features_list = ["artist","album","track_name",  "track_id","danceability","energy","key","loudness","mode", "speechiness","instrumentalness","liveness","valence","tempo", "duration_ms","time_signature"]
playlist_df = pd.DataFrame(columns = playlist_features_list)

for track in tracks:
            # Create empty dict
        playlist_features = {}
            # Get metadata
        playlist_features["artist"] = track["track"]["album"]["artists"][0]["name"]
        playlist_features["album"] = track["track"]["album"]["name"]
        playlist_features["track_name"] = track["track"]["name"]
        playlist_features["track_id"] = track["track"]["id"]
        
        # Get audio features
        audio_features = sp.audio_features(playlist_features["track_id"])[0]
        for feature in playlist_features_list[4:]:
            playlist_features[feature] = audio_features[feature]
            
            # Concat the dfs
        track_df = pd.DataFrame(playlist_features, index = [0])
        playlist_df = pd.concat([playlist_df, track_df], ignore_index = True)

# %%
playlist_df.head()
# Out:
#           artist                                              album  \
# 0      Yoke Lore                                    Spotify Singles
# 1      Yoke Lore                                           Goodpain
# 2   Hollow Coves                               The Woods (Acoustic)
# 3    Broken Back                Dear Misfortune, Mother of Joy - EP
# 4  José González  Stay Alive (From The Secret Life Of Walter Mitty)
#
#                                           track_name                track_id  \
# 0  Truly Madly Deeply - Recorded at Spotify Studi...  0hLObGB9xRjuRVasHehmLI
# 1                                              Beige  0FfZudphGgQTGeEV6AhmOs
# 2                               The Woods - Acoustic  6uaIMhUZXMuT2Zz0vxrFiR
# 3                                        Young Souls  7p2RlyF403KmPmZm2TxKl3
# 4                                         Stay Alive  0ZNYGrmcehorhh9JOeg5Iv
#
#    danceability  energy key  loudness mode  speechiness  instrumentalness  \
# 0         0.675   0.368   0   -14.072    0       0.0375          0.001580
# 1         0.434   0.677  10    -7.535    1       0.1190          0.068400
# 2         0.568   0.558   9    -8.553    1       0.0278          0.000331
# 3         0.702   0.606   8   -10.285    0       0.0443          0.000000
# 4         0.714   0.306   6   -12.111    1       0.0388          0.168000
#
#    liveness  valence    tempo duration_ms time_signature
# 0    0.1360    0.176  106.004      190393              4
# 1    0.1190    0.218  167.927      204209              4
# 2    0.1160    0.287  104.991      239960              4
# 3    0.1450    0.463   99.950      219373              4
# 4    0.0924    0.314  129.984      266907              4

# %%
artists_ids
# Out:
# ['6VCoG3MG7ZKRxDjaYOvtrF',
#  '0jRqFvRKCDryHOgrgFqsKG',
#  '0L8ExT028jH3ddEcZwqJJ5',
#  '4BxCuXFJrSWGi1KHcVqaU4',
#  '5YA1c6yVkPnflTLMfOgjzc',
#  '4gzpq5DPGxSnKTe4SA8HAU',
#  '6r1Xmz7YUD4z0VRUoGm8XN',
#  '4HV7yKF3SRpY6I0gxu7hm9',
#  '3WrFJ7ztbogyGnTHbHJFl2',
#  '2WjvvwAX0mdWwq3aFuUdtc',
#  '5sWHDYs0csV6RS48xBl0tH',
#  '0LcJLqbBmaGUft1e9Mm8HV',
#  '0SwO7SWeDHJijQ3XNS7xEE',
#  '5KORW1YGiERJqfuYjXMCyz',
#  '7jdFEYD2LTYjfwxOdlVjmc',
#  '0epOFNiUfyON9EYx7Tpr6V',
#  '1kDGbuxWknIKx4FlgWxiSp',
#  '5f7VJjfbwm532GiveGC0ZK',
#  '6u11Qbko2N2hP4lTBYjX86',
#  '10exVja0key0uqUkk6LJRT',
#  '0bzfPKdbXL5ezYW2z3UGQj',
#  '79hrYiudVcFyyxyJW0ipTy',
#  '0ZR3khgseh3xy3s8iBYWrI',
#  '6n9XmMc3mX18mrTHYOCPIq',
#  '6VxCmtR7S3yz4vnzsJqhSV',
#  '536BYVgOnRky0xjsPT96zl',
#  '0MlOPi3zIDMVrfA9R04Fe3',
#  '1cwOthlzLBwN8Imbq7P71H',
#  '59wfkuBoNyhDMQGCljbUbA',
#  '0RqtSIYZmd4fiBKVFqyIqD',
#  '3yDIp0kaq9EFKe07X1X2rz',
#  '2xaAOVImG2O6lURwqperlD',
#  '4qNZw759AdHSMugyDMrIlF',
#  '26T3LtbuGT1Fu9m0eRq5X3',
#  '5nCi3BB41mBaMH9gfr6Su0',
#  '2IS9rTtWwEfUEY4u3mecIT',
#  '49zZ2lRNpfwWfUnASUxCYW',
#  '1SFz3S9eSUTc49ysstadiO',
#  '6zvul52xwTWzilBZl6BUbT',
#  '2ysnwxxNtSgbb9t1m2Ur4j',
#  '6oX4tx055oEFYM3ahDTyOD',
#  '2qlAMLpUyBjZgnzuFXXZXI',
#  '0MmnmsAuQKRFpo6vJElcaU',
#  '2vaWvC8suCFkRXejDOK7EE',
#  '6ujr1NkqbZpYOhquczUUfl',
#  '5yBDILLJyNFAjFpECkk7ys',
#  '3nFkdlSjzX9mRTtwJOzDYB',
#  '5Qi4Bb7a8C0a00NZcA77L0',
#  '5Gpi2vZtZtUPrMnlBDdpre',
#  '7EGwUS3c5dXduO4sMyLWC5',
#  '2RQXRUsr4IW1f3mKyKsy4B',
#  '6VDdCwrBM4qQaGxoAyxyJC',
#  '0vEsuISMWAKNctLlUAhSZC',
#  '5ypxebeHEIXjMtJb17uJlI',
#  '0fA0VVWsXO9YnASrzqfmYu',
#  '7giUHu5pv6YTZgSkxxCcgh',
#  '1hJuGCUpefX24GFmss9bjH',
#  '0AkpPlFLnr0VQwZQeMGht0',
#  '4j56EQDQu5XnL7R3E9iFJT',
#  '5yV1qdnmxyIYiSFB02wpDj',
#  '0XNa1vTidXlvJ2gHSsRi4A',
#  '3JE0uoggWwwYG6rSSJk0HN',
#  '6FQqZYVfTNQ1pCqfkwVFEa',
#  '0oeUpvxWsC8bWS6SnpU8b9',
#  '3hozsZ9hqNq7CoBGYNlFTz',
#  '6aZyMrc4doVtZyKNilOmwu',
#  '1gRNBaI4yn6wCCTvRhGWh8',
#  '5K4W6rqBFWDnAN6FQUkS6x',
#  '6kACVPfCOnqzgfEF5ryl0x',
#  '7KMqksf0UMdyA0UCf4R3ux',
#  '0iui2Be5CP8EWxvHYsVspL',
#  '09hVIj6vWgoCDtT03h8ZCa',
#  '6edGSAX5dVpeJVwu1Q0NwJ',
#  '7Ln80lUS6He07XvHI8qqHH',
#  '6hV6oxGLeLFw17DGjIPkYD',
#  '1FmnkGJ5KDt1eCHJQVyAbk',
#  '5o206eFLx38glA2bb4zqIU',
#  '4dwdTW1Lfiq0cM8nBAqIIz',
#  '7gP3bB2nilZXLfPHJhMdvc',
#  '7knmbOGe07k85GmK50vACB',
#  '7dGJo4pcD2V6oG8kP0tJRR',
#  '7mnBLXK823vNxN3UWB7Gfz',
#  '3oDbviiivRWhXwIE8hxkVV',
#  '6ueGR6SWhUJfvEhqkvMsVs',
#  '1xU878Z1QtBldR7ru9owdU',
#  '5schNIzWdI9gJ1QRK8SBnc',
#  '04gDigrS5kc9YWfZHwBETP',
#  '3LTYeDqM0ojTaTpsi63puM',
#  '3jOstUTkEu2JkjvRdBA5Gu',
#  '70AkqfU43ou9hFxJZTDt7A',
#  '0yb46jwm7gqbZXVXZQ8Z1e',
#  '70cRZdQywnSFp9pnc2WTCE',
#  '3PhoLpVuITZKcymswpck5b',
#  '4tvKz56Tr39bkhcQUTO0Xr',
#  '75EZuo5MHV2572NRpMWotC',
#  '42TFhl7WlMRXiNqzSrnzPL',
#  '3M0H4efyA5YcijrKlaKbYn',
#  '3rIZMv9rysU7JkLzEaC5Jp',
#  '204c5kep4L9kpSktmP03VT',
#  '69tiO1fG8VWduDl3ji2qhI',
#  '1yxSLGMDHlW21z4YXirZDS',
#  '0C0XlULifJtAgn6ZNCW2eu',
#  '7xTcuBOIAAIGDOSvwYFPzk',
#  '1Zp054Jc86WVKCxKEqZGOA',
#  '7EQ0qTo7fWT7DPxmxtSYEc',
#  '5NDMothbpdpq2xHqSjrrWn',
#  '4EzkuveR9pLvDVFNx6foYD',
#  '22bE4uQ6baNwSHPVcDxLCe',
#  '1hzfo8twXdOegF3xireCYs',
#  '4W48hZAnAHVOC2c8WH8pcq',
#  '2txHhyCwHjUEpJjWrEyqyX',
#  '3GBPw9NK25X1Wt2OUvOwY3',
#  '3OsRAKCvk37zwYcnzRf5XF',
#  '2Z7UcsdweVlRbAk5wH5fsf',
#  '0OdUWJ0sBjDrqHygGUXeCF',
#  '1eIoJGCu3rShrRm2wfOhN8',
#  '31TPClRtHm23RisEBtV3X7',
#  '7Ey4PD4MYsKc5I2dolUwbH',
#  '5wD0owYApRtYmjPWavWKvb',
#  '1aX2dmV8XoHYCOQRxjPESG',
#  '0XHM5ZNJDU8e4CfbWMeSzC',
#  '6P5NO5hzJbuOqSdyPB7SJM',
#  '6tuPdaFPIytg3l2f51L7Hw',
#  '3ngKsDXZAssmljeXCvEgOe',
#  '6zFYqv1mOsgBRQbae3JJ9e',
#  '6CpNuq0rsIj6Il313E6lKL',
#  '6d9XIbBseVi999qdzDEtwE',
#  '4Z8W4fKeB5YxbusRsdQVPb',
#  '77SW9BnxLY8rJ0RciFqkHh',
#  '5BvJzeQpmsdsFp4HGUYUEx',
#  '56UIK6wmbbxuQ6VA20vrWD',
#  '3XHO7cRUPCLOr6jwp8vsx5',
#  '0vW8z9pZMGCcRtGPGtyqiB',
#  '6xrCU6zdcSTsG2hLrojpmI',
#  '2oqwwcM17wrP9hBD25zKSR',
#  '2qk9voo8llSGYcZ6xrBzKx',
#  '2FXC3k01G6Gw61bmprjgqS',
#  '0id62QV2SZZfvBn9xpmuCl',
#  '4kI8Ie27vjvonwaB2ePh8T',
#  '6FBDaR13swtiWwGhX1WQsP',
#  '4phGZZrJZRo4ElhRtViYdl',
#  '0xXyoA3JyBv8EHzm66kH4J',
#  '2RdwBSPQiwcmiDo9kixcl8',
#  '1Xyo4u8uXC1ZmMpatF05PJ',
#  '3nqQeOUvDPTu4vtYtPfBjX',
#  '4LLpKhyESsyAXpc4laK94U',
#  '47wB3vlOd130dM3k5fADQw',
#  '1rAv1GhTQ2rmG94p9lU3rB',
#  '7IAFAOtc9kTYNTizhLSWM6',
#  '7urq0VfqxEYEEiZUkebXT4',
#  '1ctkBmvz80MGyi72Ix055S',
#  '53XhwfbYqKCa1cC15pYq2q',
#  '7oPftvlwr6VrsViSDV7fJY',
#  '54QMjE4toDfiCryzYWCpXX',
#  '1GLtl8uqKmnyCWxHmw9tL4',
#  '0zOcE3mg9nS6l3yxt1Y0bK',
#  '513t0jZUP0K98C4h7KHtEb',
#  '4DToQR3aKrHQSSRzSz8Nzt',
#  '1dWEYMPtNmvSVaDNLgB6NV',
#  '21K0gLOe4i0o6l1MHd5a6W',
#  '0oSGxfWSnnOXhD2fKuz2Gy',
#  '3TNt4aUIxgfy9aoaft5Jj2',
#  '6XyY86QOPPrYVGvF9ch6wz',
#  '16oZKvXb6WkQlVAjwo2Wbg',
#  '7FU0xCgmSYQEiBeevUqQ4S',
#  '7gHscNMDI8FF8pcgrV8eIn',
#  '1SQRv42e4PjEYfPhS0Tk9E',
#  '7wrulS1dfanckBnoxxEuS6',
#  '2DaxqgrOhkeH0fpeiQq2f4',
#  '7zsin6IgVsR1rqSRCNYDwq',
#  '0k17h0D3J5VfsdmQ1iZtE9',
#  '3kjuyTCjPG1WMFCiyc5IuB',
#  '1AgxgADPuRIW1wyaA4OKcB',
#  '4nx8ehrFiCOmWgebUKshDV',
#  '6olE6TJLqED3rqDCT0FyPh',
#  '4tZwfgrHOc3mvqYlEYSvVi',
#  '1fa0cOhromAZdq2xRA4vv8',
#  '1dfeR4HaWDbWqFHLkxsg1d']

# %%
results = sp.artist_top_tracks('6VCoG3MG7ZKRxDjaYOvtrF')
results
# Out:
# {'tracks': [{'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6VCoG3MG7ZKRxDjaYOvtrF'},
#       'href': 'https://api.spotify.com/v1/artists/6VCoG3MG7ZKRxDjaYOvtrF',
#       'id': '6VCoG3MG7ZKRxDjaYOvtrF',
#       'name': 'Love of Lesbian',
#       'type': 'artist',
#       'uri': 'spotify:artist:6VCoG3MG7ZKRxDjaYOvtrF'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/1vvfLVVcU1o8sPMq25CxpF'},
#     'href': 'https://api.spotify.com/v1/albums/1vvfLVVcU1o8sPMq25CxpF',
#     'id': '1vvfLVVcU1o8sPMq25CxpF',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273304dbb3e13db9dae376c7a51',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02304dbb3e13db9dae376c7a51',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851304dbb3e13db9dae376c7a51',
#       'width': 64}],
#     'name': '1999 (o como generar incendios de nieve con una lupa enfocando la luna)',
#     'release_date': '2009-03-24',
#     'release_date_precision': 'day',
#     'total_tracks': 14,
#     'type': 'album',
#     'uri': 'spotify:album:1vvfLVVcU1o8sPMq25CxpF'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6VCoG3MG7ZKRxDjaYOvtrF'},
#      'href': 'https://api.spotify.com/v1/artists/6VCoG3MG7ZKRxDjaYOvtrF',
#      'id': '6VCoG3MG7ZKRxDjaYOvtrF',
#      'name': 'Love of Lesbian',
#      'type': 'artist',
#      'uri': 'spotify:artist:6VCoG3MG7ZKRxDjaYOvtrF'}],
#    'disc_number': 1,
#    'duration_ms': 337453,
#    'explicit': False,
#    'external_ids': {'isrc': 'ES7650900037'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/29tVNOmg85qDLh2wVnJxpv'},
#    'href': 'https://api.spotify.com/v1/tracks/29tVNOmg85qDLh2wVnJxpv',
#    'id': '29tVNOmg85qDLh2wVnJxpv',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'Allí donde solíamos gritar',
#    'popularity': 56,
#    'preview_url': 'https://p.scdn.co/mp3-preview/26fcb7ff3c7113f41ccf46ffda8c9c318f37d31b?cid=cf245f23e4a6465d816f3d4b131c8dcd',
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:29tVNOmg85qDLh2wVnJxpv'},
#   {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6VCoG3MG7ZKRxDjaYOvtrF'},
#       'href': 'https://api.spotify.com/v1/artists/6VCoG3MG7ZKRxDjaYOvtrF',
#       'id': '6VCoG3MG7ZKRxDjaYOvtrF',
#       'name': 'Love of Lesbian',
#       'type': 'artist',
#       'uri': 'spotify:artist:6VCoG3MG7ZKRxDjaYOvtrF'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/1vvfLVVcU1o8sPMq25CxpF'},
#     'href': 'https://api.spotify.com/v1/albums/1vvfLVVcU1o8sPMq25CxpF',
#     'id': '1vvfLVVcU1o8sPMq25CxpF',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273304dbb3e13db9dae376c7a51',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02304dbb3e13db9dae376c7a51',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851304dbb3e13db9dae376c7a51',
#       'width': 64}],
#     'name': '1999 (o como generar incendios de nieve con una lupa enfocando la luna)',
#     'release_date': '2009-03-24',
#     'release_date_precision': 'day',
#     'total_tracks': 14,
#     'type': 'album',
#     'uri': 'spotify:album:1vvfLVVcU1o8sPMq25CxpF'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6VCoG3MG7ZKRxDjaYOvtrF'},
#      'href': 'https://api.spotify.com/v1/artists/6VCoG3MG7ZKRxDjaYOvtrF',
#      'id': '6VCoG3MG7ZKRxDjaYOvtrF',
#      'name': 'Love of Lesbian',
#      'type': 'artist',
#      'uri': 'spotify:artist:6VCoG3MG7ZKRxDjaYOvtrF'}],
#    'disc_number': 1,
#    'duration_ms': 231160,
#    'explicit': False,
#    'external_ids': {'isrc': 'ES7650900038'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/1KhqSLS8YafrUCbjrn8WxZ'},
#    'href': 'https://api.spotify.com/v1/tracks/1KhqSLS8YafrUCbjrn8WxZ',
#    'id': '1KhqSLS8YafrUCbjrn8WxZ',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'Club de fans de John Boy',
#    'popularity': 55,
#    'preview_url': 'https://p.scdn.co/mp3-preview/958a63d13de2171fc3ea23e080b99e6619c4a595?cid=cf245f23e4a6465d816f3d4b131c8dcd',
#    'track_number': 2,
#    'type': 'track',
#    'uri': 'spotify:track:1KhqSLS8YafrUCbjrn8WxZ'},
#   {'album': {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6VCoG3MG7ZKRxDjaYOvtrF'},
#       'href': 'https://api.spotify.com/v1/artists/6VCoG3MG7ZKRxDjaYOvtrF',
#       'id': '6VCoG3MG7ZKRxDjaYOvtrF',
#       'name': 'Love of Lesbian',
#       'type': 'artist',
#       'uri': 'spotify:artist:6VCoG3MG7ZKRxDjaYOvtrF'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/3xLrBbrCZZL6aYvTCXWtvS'},
#     'href': 'https://api.spotify.com/v1/albums/3xLrBbrCZZL6aYvTCXWtvS',
#     'id': '3xLrBbrCZZL6aYvTCXWtvS',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2738476bebb0d23f4240c2caba6',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e028476bebb0d23f4240c2caba6',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048518476bebb0d23f4240c2caba6',
#       'width': 64}],
#     'name': 'Fantastic Shine',
#     'release_date': '2013-06-04',
#     'release_date_precision': 'day',
#     'total_tracks': 1,
#     'type': 'album',
#     'uri': 'spotify:album:3xLrBbrCZZL6aYvTCXWtvS'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6VCoG3MG7ZKRxDjaYOvtrF'},
#      'href': 'https://api.spotify.com/v1/artists/6VCoG3MG7ZKRxDjaYOvtrF',
#      'id': '6VCoG3MG7ZKRxDjaYOvtrF',
#      'name': 'Love of Lesbian',
#      'type': 'artist',
#      'uri': 'spotify:artist:6VCoG3MG7ZKRxDjaYOvtrF'}],
#    'disc_number': 1,
#    'duration_ms': 182125,
#    'explicit': False,
#    'external_ids': {'isrc': 'ES7651300037'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/3Ti0O0JrzCJ3Hxdgg6YI1V'},
#    'href': 'https://api.spotify.com/v1/tracks/3Ti0O0JrzCJ3Hxdgg6YI1V',
#    'id': '3Ti0O0JrzCJ3Hxdgg6YI1V',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'Fantastic Shine',
#    'popularity': 54,
#    'preview_url': 'https://p.scdn.co/mp3-preview/c2b249e4836cc2714deea3059493c63f3a1ffae1?cid=cf245f23e4a6465d816f3d4b131c8dcd',
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:3Ti0O0JrzCJ3Hxdgg6YI1V'},
#   {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6VCoG3MG7ZKRxDjaYOvtrF'},
#       'href': 'https://api.spotify.com/v1/artists/6VCoG3MG7ZKRxDjaYOvtrF',
#       'id': '6VCoG3MG7ZKRxDjaYOvtrF',
#       'name': 'Love of Lesbian',
#       'type': 'artist',
#       'uri': 'spotify:artist:6VCoG3MG7ZKRxDjaYOvtrF'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/0JZ2SeWiwq3mk7Po6yIeF8'},
#     'href': 'https://api.spotify.com/v1/albums/0JZ2SeWiwq3mk7Po6yIeF8',
#     'id': '0JZ2SeWiwq3mk7Po6yIeF8',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b27358a88e0cc35ee288937be6dd',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e0258a88e0cc35ee288937be6dd',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d0000485158a88e0cc35ee288937be6dd',
#       'width': 64}],
#     'name': 'V.E.H.N. (Viaje épico hacia la nada)',
#     'release_date': '2021-04-16',
#     'release_date_precision': 'day',
#     'total_tracks': 12,
#     'type': 'album',
#     'uri': 'spotify:album:0JZ2SeWiwq3mk7Po6yIeF8'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6VCoG3MG7ZKRxDjaYOvtrF'},
#      'href': 'https://api.spotify.com/v1/artists/6VCoG3MG7ZKRxDjaYOvtrF',
#      'id': '6VCoG3MG7ZKRxDjaYOvtrF',
#      'name': 'Love of Lesbian',
#      'type': 'artist',
#      'uri': 'spotify:artist:6VCoG3MG7ZKRxDjaYOvtrF'}],
#    'disc_number': 1,
#    'duration_ms': 288873,
#    'explicit': False,
#    'external_ids': {'isrc': 'ES5152000846'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/6KpO7aV711k0WZOmvLCjGX'},
#    'href': 'https://api.spotify.com/v1/tracks/6KpO7aV711k0WZOmvLCjGX',
#    'id': '6KpO7aV711k0WZOmvLCjGX',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'Los irrompibles',
#    'popularity': 48,
#    'preview_url': 'https://p.scdn.co/mp3-preview/a4cd6b97b26c6a77bf6af4d82dddac01ccc4e238?cid=cf245f23e4a6465d816f3d4b131c8dcd',
#    'track_number': 8,
#    'type': 'track',
#    'uri': 'spotify:track:6KpO7aV711k0WZOmvLCjGX'},
#   {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6VCoG3MG7ZKRxDjaYOvtrF'},
#       'href': 'https://api.spotify.com/v1/artists/6VCoG3MG7ZKRxDjaYOvtrF',
#       'id': '6VCoG3MG7ZKRxDjaYOvtrF',
#       'name': 'Love of Lesbian',
#       'type': 'artist',
#       'uri': 'spotify:artist:6VCoG3MG7ZKRxDjaYOvtrF'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/0JZ2SeWiwq3mk7Po6yIeF8'},
#     'href': 'https://api.spotify.com/v1/albums/0JZ2SeWiwq3mk7Po6yIeF8',
#     'id': '0JZ2SeWiwq3mk7Po6yIeF8',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b27358a88e0cc35ee288937be6dd',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e0258a88e0cc35ee288937be6dd',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d0000485158a88e0cc35ee288937be6dd',
#       'width': 64}],
#     'name': 'V.E.H.N. (Viaje épico hacia la nada)',
#     'release_date': '2021-04-16',
#     'release_date_precision': 'day',
#     'total_tracks': 12,
#     'type': 'album',
#     'uri': 'spotify:album:0JZ2SeWiwq3mk7Po6yIeF8'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6VCoG3MG7ZKRxDjaYOvtrF'},
#      'href': 'https://api.spotify.com/v1/artists/6VCoG3MG7ZKRxDjaYOvtrF',
#      'id': '6VCoG3MG7ZKRxDjaYOvtrF',
#      'name': 'Love of Lesbian',
#      'type': 'artist',
#      'uri': 'spotify:artist:6VCoG3MG7ZKRxDjaYOvtrF'}],
#    'disc_number': 1,
#    'duration_ms': 285137,
#    'explicit': False,
#    'external_ids': {'isrc': 'ES5152000841'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/7E7mQSmMVCZHbofahjDkDA'},
#    'href': 'https://api.spotify.com/v1/tracks/7E7mQSmMVCZHbofahjDkDA',
#    'id': '7E7mQSmMVCZHbofahjDkDA',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'Sesenta memorias perdidas',
#    'popularity': 52,
#    'preview_url': 'https://p.scdn.co/mp3-preview/ff1633f6559f4d8b4a0d99697305728a3cbbcf38?cid=cf245f23e4a6465d816f3d4b131c8dcd',
#    'track_number': 3,
#    'type': 'track',
#    'uri': 'spotify:track:7E7mQSmMVCZHbofahjDkDA'},
#   {'album': {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6VCoG3MG7ZKRxDjaYOvtrF'},
#       'href': 'https://api.spotify.com/v1/artists/6VCoG3MG7ZKRxDjaYOvtrF',
#       'id': '6VCoG3MG7ZKRxDjaYOvtrF',
#       'name': 'Love of Lesbian',
#       'type': 'artist',
#       'uri': 'spotify:artist:6VCoG3MG7ZKRxDjaYOvtrF'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/3qUrABCNqnkb5gc2YmPVzP'},
#       'href': 'https://api.spotify.com/v1/artists/3qUrABCNqnkb5gc2YmPVzP',
#       'id': '3qUrABCNqnkb5gc2YmPVzP',
#       'name': 'Ivan Ferreiro',
#       'type': 'artist',
#       'uri': 'spotify:artist:3qUrABCNqnkb5gc2YmPVzP'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/0BcjE2qk4Wn8CZXSLw6V6T'},
#     'href': 'https://api.spotify.com/v1/albums/0BcjE2qk4Wn8CZXSLw6V6T',
#     'id': '0BcjE2qk4Wn8CZXSLw6V6T',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273fef66cee0f219d65e6e593b2',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02fef66cee0f219d65e6e593b2',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851fef66cee0f219d65e6e593b2',
#       'width': 64}],
#     'name': 'La fuerza del destino',
#     'release_date': '2019-03-22',
#     'release_date_precision': 'day',
#     'total_tracks': 1,
#     'type': 'album',
#     'uri': 'spotify:album:0BcjE2qk4Wn8CZXSLw6V6T'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6VCoG3MG7ZKRxDjaYOvtrF'},
#      'href': 'https://api.spotify.com/v1/artists/6VCoG3MG7ZKRxDjaYOvtrF',
#      'id': '6VCoG3MG7ZKRxDjaYOvtrF',
#      'name': 'Love of Lesbian',
#      'type': 'artist',
#      'uri': 'spotify:artist:6VCoG3MG7ZKRxDjaYOvtrF'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/3qUrABCNqnkb5gc2YmPVzP'},
#      'href': 'https://api.spotify.com/v1/artists/3qUrABCNqnkb5gc2YmPVzP',
#      'id': '3qUrABCNqnkb5gc2YmPVzP',
#      'name': 'Ivan Ferreiro',
#      'type': 'artist',
#      'uri': 'spotify:artist:3qUrABCNqnkb5gc2YmPVzP'}],
#    'disc_number': 1,
#    'duration_ms': 299375,
#    'explicit': False,
#    'external_ids': {'isrc': 'ES5151900176'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/6wv3q2XbKeAfyur3iuJFeK'},
#    'href': 'https://api.spotify.com/v1/tracks/6wv3q2XbKeAfyur3iuJFeK',
#    'id': '6wv3q2XbKeAfyur3iuJFeK',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'La fuerza del destino',
#    'popularity': 51,
#    'preview_url': 'https://p.scdn.co/mp3-preview/be5729d3b01af3ba1decb5cf40177ed1d7f86e9a?cid=cf245f23e4a6465d816f3d4b131c8dcd',
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:6wv3q2XbKeAfyur3iuJFeK'},
#   {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6VCoG3MG7ZKRxDjaYOvtrF'},
#       'href': 'https://api.spotify.com/v1/artists/6VCoG3MG7ZKRxDjaYOvtrF',
#       'id': '6VCoG3MG7ZKRxDjaYOvtrF',
#       'name': 'Love of Lesbian',
#       'type': 'artist',
#       'uri': 'spotify:artist:6VCoG3MG7ZKRxDjaYOvtrF'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/5hj8ChEpOgHmVTqUuZFz82'},
#     'href': 'https://api.spotify.com/v1/albums/5hj8ChEpOgHmVTqUuZFz82',
#     'id': '5hj8ChEpOgHmVTqUuZFz82',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2734761a64109aafd6a1084af2e',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e024761a64109aafd6a1084af2e',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048514761a64109aafd6a1084af2e',
#       'width': 64}],
#     'name': 'El Poeta Halley',
#     'release_date': '2016-03-04',
#     'release_date_precision': 'day',
#     'total_tracks': 13,
#     'type': 'album',
#     'uri': 'spotify:album:5hj8ChEpOgHmVTqUuZFz82'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6VCoG3MG7ZKRxDjaYOvtrF'},
#      'href': 'https://api.spotify.com/v1/artists/6VCoG3MG7ZKRxDjaYOvtrF',
#      'id': '6VCoG3MG7ZKRxDjaYOvtrF',
#      'name': 'Love of Lesbian',
#      'type': 'artist',
#      'uri': 'spotify:artist:6VCoG3MG7ZKRxDjaYOvtrF'}],
#    'disc_number': 1,
#    'duration_ms': 310586,
#    'explicit': False,
#    'external_ids': {'isrc': 'ES5151503889'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/7cU9WoW8e06g6EwKXHnU2q'},
#    'href': 'https://api.spotify.com/v1/tracks/7cU9WoW8e06g6EwKXHnU2q',
#    'id': '7cU9WoW8e06g6EwKXHnU2q',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'Cuando no me ves',
#    'popularity': 51,
#    'preview_url': 'https://p.scdn.co/mp3-preview/9af77ec03073b13af8507d7a6200b8c38a33ab93?cid=cf245f23e4a6465d816f3d4b131c8dcd',
#    'track_number': 3,
#    'type': 'track',
#    'uri': 'spotify:track:7cU9WoW8e06g6EwKXHnU2q'},
#   {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6VCoG3MG7ZKRxDjaYOvtrF'},
#       'href': 'https://api.spotify.com/v1/artists/6VCoG3MG7ZKRxDjaYOvtrF',
#       'id': '6VCoG3MG7ZKRxDjaYOvtrF',
#       'name': 'Love of Lesbian',
#       'type': 'artist',
#       'uri': 'spotify:artist:6VCoG3MG7ZKRxDjaYOvtrF'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/5hj8ChEpOgHmVTqUuZFz82'},
#     'href': 'https://api.spotify.com/v1/albums/5hj8ChEpOgHmVTqUuZFz82',
#     'id': '5hj8ChEpOgHmVTqUuZFz82',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2734761a64109aafd6a1084af2e',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e024761a64109aafd6a1084af2e',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048514761a64109aafd6a1084af2e',
#       'width': 64}],
#     'name': 'El Poeta Halley',
#     'release_date': '2016-03-04',
#     'release_date_precision': 'day',
#     'total_tracks': 13,
#     'type': 'album',
#     'uri': 'spotify:album:5hj8ChEpOgHmVTqUuZFz82'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6VCoG3MG7ZKRxDjaYOvtrF'},
#      'href': 'https://api.spotify.com/v1/artists/6VCoG3MG7ZKRxDjaYOvtrF',
#      'id': '6VCoG3MG7ZKRxDjaYOvtrF',
#      'name': 'Love of Lesbian',
#      'type': 'artist',
#      'uri': 'spotify:artist:6VCoG3MG7ZKRxDjaYOvtrF'}],
#    'disc_number': 1,
#    'duration_ms': 347106,
#    'explicit': False,
#    'external_ids': {'isrc': 'ES5151503886'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/524CYK7MKCn29GBQvQluzG'},
#    'href': 'https://api.spotify.com/v1/tracks/524CYK7MKCn29GBQvQluzG',
#    'id': '524CYK7MKCn29GBQvQluzG',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'Bajo el volcán',
#    'popularity': 50,
#    'preview_url': 'https://p.scdn.co/mp3-preview/9e74216af1d4b89a50c87a69d090d09fec2bf681?cid=cf245f23e4a6465d816f3d4b131c8dcd',
#    'track_number': 2,
#    'type': 'track',
#    'uri': 'spotify:track:524CYK7MKCn29GBQvQluzG'},
#   {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6VCoG3MG7ZKRxDjaYOvtrF'},
#       'href': 'https://api.spotify.com/v1/artists/6VCoG3MG7ZKRxDjaYOvtrF',
#       'id': '6VCoG3MG7ZKRxDjaYOvtrF',
#       'name': 'Love of Lesbian',
#       'type': 'artist',
#       'uri': 'spotify:artist:6VCoG3MG7ZKRxDjaYOvtrF'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/5hj8ChEpOgHmVTqUuZFz82'},
#     'href': 'https://api.spotify.com/v1/albums/5hj8ChEpOgHmVTqUuZFz82',
#     'id': '5hj8ChEpOgHmVTqUuZFz82',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2734761a64109aafd6a1084af2e',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e024761a64109aafd6a1084af2e',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048514761a64109aafd6a1084af2e',
#       'width': 64}],
#     'name': 'El Poeta Halley',
#     'release_date': '2016-03-04',
#     'release_date_precision': 'day',
#     'total_tracks': 13,
#     'type': 'album',
#     'uri': 'spotify:album:5hj8ChEpOgHmVTqUuZFz82'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6VCoG3MG7ZKRxDjaYOvtrF'},
#      'href': 'https://api.spotify.com/v1/artists/6VCoG3MG7ZKRxDjaYOvtrF',
#      'id': '6VCoG3MG7ZKRxDjaYOvtrF',
#      'name': 'Love of Lesbian',
#      'type': 'artist',
#      'uri': 'spotify:artist:6VCoG3MG7ZKRxDjaYOvtrF'}],
#    'disc_number': 1,
#    'duration_ms': 445213,
#    'explicit': False,
#    'external_ids': {'isrc': 'ES5151503885'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/0tZYFh6kyraGwBs5VSR3HL'},
#    'href': 'https://api.spotify.com/v1/tracks/0tZYFh6kyraGwBs5VSR3HL',
#    'id': '0tZYFh6kyraGwBs5VSR3HL',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'El poeta Halley',
#    'popularity': 48,
#    'preview_url': 'https://p.scdn.co/mp3-preview/8060ec34e66e8be0d42dd931d3e18fe4027d79fc?cid=cf245f23e4a6465d816f3d4b131c8dcd',
#    'track_number': 13,
#    'type': 'track',
#    'uri': 'spotify:track:0tZYFh6kyraGwBs5VSR3HL'},
#   {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6VCoG3MG7ZKRxDjaYOvtrF'},
#       'href': 'https://api.spotify.com/v1/artists/6VCoG3MG7ZKRxDjaYOvtrF',
#       'id': '6VCoG3MG7ZKRxDjaYOvtrF',
#       'name': 'Love of Lesbian',
#       'type': 'artist',
#       'uri': 'spotify:artist:6VCoG3MG7ZKRxDjaYOvtrF'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/0JZ2SeWiwq3mk7Po6yIeF8'},
#     'href': 'https://api.spotify.com/v1/albums/0JZ2SeWiwq3mk7Po6yIeF8',
#     'id': '0JZ2SeWiwq3mk7Po6yIeF8',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b27358a88e0cc35ee288937be6dd',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e0258a88e0cc35ee288937be6dd',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d0000485158a88e0cc35ee288937be6dd',
#       'width': 64}],
#     'name': 'V.E.H.N. (Viaje épico hacia la nada)',
#     'release_date': '2021-04-16',
#     'release_date_precision': 'day',
#     'total_tracks': 12,
#     'type': 'album',
#     'uri': 'spotify:album:0JZ2SeWiwq3mk7Po6yIeF8'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6VCoG3MG7ZKRxDjaYOvtrF'},
#      'href': 'https://api.spotify.com/v1/artists/6VCoG3MG7ZKRxDjaYOvtrF',
#      'id': '6VCoG3MG7ZKRxDjaYOvtrF',
#      'name': 'Love of Lesbian',
#      'type': 'artist',
#      'uri': 'spotify:artist:6VCoG3MG7ZKRxDjaYOvtrF'}],
#    'disc_number': 1,
#    'duration_ms': 245550,
#    'explicit': False,
#    'external_ids': {'isrc': 'ES5152000842'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/53lqxcwtGCdYuOtLT7WvMm'},
#    'href': 'https://api.spotify.com/v1/tracks/53lqxcwtGCdYuOtLT7WvMm',
#    'id': '53lqxcwtGCdYuOtLT7WvMm',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'Cosmos (Antisistema Solar)',
#    'popularity': 48,
#    'preview_url': 'https://p.scdn.co/mp3-preview/ce5676b181659d2c8873c2938279ef7bb4c2494c?cid=cf245f23e4a6465d816f3d4b131c8dcd',
#    'track_number': 5,
#    'type': 'track',
#    'uri': 'spotify:track:53lqxcwtGCdYuOtLT7WvMm'}]}

# %%
def artist_top_tracks(artist_id):
    top_tracks = []
    results = sp.artist_top_tracks(artist_id)
    tracks = results['tracks']
    for t in tracks:
        top_tracks.append(t['id'])
    
    return top_tracks

# %%
top_tracks = artist_top_tracks("6VCoG3MG7ZKRxDjaYOvtrF")

# %%
results_tt = sp.artist_top_tracks('6VCoG3MG7ZKRxDjaYOvtrF')
tracks_tt = results_tt['tracks']

for t in tracks_tt:
            # Create empty dict
        top_tracks_features = {}
            # Get metadata
        top_tracks_features["artist"] = t["artists"]
        top_tracks_features["album"] = t["album"]['name']
        top_tracks_features["track_name"] = t["name"]
        top_tracks_features["track_id"] = t['id']
        
        # Get audio features
        audio_features = sp.audio_features(playlist_features["track_id"])[0]
        for feature in playlist_features_list[4:]:
            playlist_features[feature] = audio_features[feature]
            
            # Concat the dfs
        top_tracks_df = pd.DataFrame(top_tracks_features, index = [0])
        #playlist_df = pd.concat([playlist_df, track_df], ignore_index = True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /usr/local/Caskroom/miniconda/base/envs/ironhack_1/lib/python3.8/site-packages/pandas/core/internals/managers.py in create_block_manager_from_arrays(arrays, names, axes, consolidate)
#    1773         blocks = _form_blocks(arrays, names, axes, consolidate)
# -> 1774         mgr = BlockManager(blocks, axes)
#    1775     except ValueError as e:
#
# /usr/local/Caskroom/miniconda/base/envs/ironhack_1/lib/python3.8/site-packages/pandas/core/internals/managers.py in __init__(self, blocks, axes, verify_integrity)
#     913
# --> 914             self._verify_integrity()
#     915
#
# /usr/local/Caskroom/miniconda/base/envs/ironhack_1/lib/python3.8/site-packages/pandas/core/internals/managers.py in _verify_integrity(self)
#     920             if block.shape[1:] != mgr_shape[1:]:
# --> 921                 raise construction_error(tot_items, block.shape[1:], self.axes)
#     922         if len(self.items) != tot_items:
#
# ValueError: Shape of passed values is (2, 4), indices imply (1, 4)
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-60-1d441d19357c> in <module>
#      17
#      18             # Concat the dfs
# ---> 19         top_tracks_df = pd.DataFrame(top_tracks_features, index = [0])
#      20         #playlist_df = pd.concat([playlist_df, track_df], ignore_index = True)
#
# /usr/local/Caskroom/miniconda/base/envs/ironhack_1/lib/python3.8/site-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     612         elif isinstance(data, dict):
#     613             # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 614             mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     615         elif isinstance(data, ma.MaskedArray):
#     616             import numpy.ma.mrecords as mrecords
#
# /usr/local/Caskroom/miniconda/base/envs/ironhack_1/lib/python3.8/site-packages/pandas/core/internals/construction.py in dict_to_mgr(data, index, columns, dtype, typ, copy)
#     462         # TODO: can we get rid of the dt64tz special case above?
#     463
# --> 464     return arrays_to_mgr(
#     465         arrays, data_names, index, columns, dtype=dtype, typ=typ, consolidate=copy
#     466     )
#
# /usr/local/Caskroom/miniconda/base/envs/ironhack_1/lib/python3.8/site-packages/pandas/core/internals/construction.py in arrays_to_mgr(arrays, arr_names, index, columns, dtype, verify_integrity, typ, consolidate)
#     133
#     134     if typ == "block":
# --> 135         return create_block_manager_from_arrays(
#     136             arrays, arr_names, axes, consolidate=consolidate
#     137         )
#
# /usr/local/Caskroom/miniconda/base/envs/ironhack_1/lib/python3.8/site-packages/pandas/core/internals/managers.py in create_block_manager_from_arrays(arrays, names, axes, consolidate)
#    1774         mgr = BlockManager(blocks, axes)
#    1775     except ValueError as e:
# -> 1776         raise construction_error(len(arrays), arrays[0].shape, axes, e)
#    1777     if consolidate:
#    1778         mgr._consolidate_inplace()
#
# ValueError: Shape of passed values is (2, 4), indices imply (1, 4)

# %%
top_tracks_df
